# %%
import os
import json
import pandas as pd
directory = 'data'
  
ls = []
ls_for_index = []
for index, filename in enumerate(os.scandir(directory)):
    if filename.is_file():
        if str(filename.path).startswith('data\CoWIN_IN_16_2021'):
            f = open(filename.path,)
            data = json.load(f)
            ls.append(data)
            ls_for_index.append(filename.path.split('\\')[1].split('.')[0].split('16_')[1])

# %%
df = pd.DataFrame() 
df['index'] = ls_for_index
df.set_index('index')
ls_total_sites = []
for i in range(len(ls)):
    try:
        ls_total_sites.append(ls[i]['topBlock']['sites']['total'])
    except:
        ls_total_sites.append(None)
df['total_sites'] = ls_total_sites

ls_govt_sites = []
for i in range(len(ls)):
    try:
        ls_govt_sites.append(ls[i]['topBlock']['sites']['govt'])
    except:
        ls_govt_sites.append(None)
df['govt_sites'] = ls_govt_sites

ls_pvt_sites = []
for i in range(len(ls)):
    try:
        ls_pvt_sites.append(ls[i]['topBlock']['sites']['pvt'])
    except:
        ls_pvt_sites.append(None)
df['pvt_sites'] = ls_pvt_sites
df = df.reset_index(drop=True)

# %%
print(ls[0])
# Out:
# {'topBlock': {'sites': {'total': 2691, 'govt': 2331, 'pvt': 360, 'today': None}, 'sessions': {'total': 331650, 'govt': 274450, 'pvt': 57200, 'today': None}, 'registration': {'total': None, 'male': None, 'female': None, 'others': None, 'today': None}, 'vaccination': {'total': 743007, 'male': 341256, 'female': 401647, 'others': 104, 'covishield': 736102, 'covaxin': 6852, 'today': 63344}}, 'vaccinationDoneByTime': [{'ts': '2021-03-08T06:00:00.000Z', 'timestamps': '2021-03-08T12:00:00.000Z', 'label': '12:00-13:00', 'count': 8364, 'dose_one': 6263, 'dose_two': 2101}, {'ts': '2021-03-08T08:00:00.000Z', 'timestamps': '2021-03-08T14:00:00.000Z', 'label': '14:00-15:00', 'count': 9066, 'dose_one': 6539, 'dose_two': 2527}, {'ts': '2021-03-08T10:00:00.000Z', 'timestamps': '2021-03-08T16:00:00.000Z', 'label': '16:00-17:00', 'count': 9476, 'dose_one': 6036, 'dose_two': 3440}, {'ts': '2021-03-08T12:00:00.000Z', 'timestamps': '2021-03-08T18:00:00.000Z', 'label': '18:00-19:00', 'count': 1746, 'dose_one': 1160, 'dose_two': 586}, {'ts': '2021-03-08T13:00:00.000Z', 'timestamps': '2021-03-08T19:00:00.000Z', 'label': '19:00-20:00', 'count': 769, 'dose_one': 441, 'dose_two': 328}, {'ts': '2021-03-08T17:00:00.000Z', 'timestamps': '2021-03-08T23:00:00.000Z', 'label': '23:00-00:00', 'count': 42, 'dose_one': 26, 'dose_two': 16}, {'ts': '2021-03-08T09:00:00.000Z', 'timestamps': '2021-03-08T15:00:00.000Z', 'label': '15:00-16:00', 'count': 9157, 'dose_one': 5893, 'dose_two': 3264}, {'ts': '2021-03-08T07:00:00.000Z', 'timestamps': '2021-03-08T13:00:00.000Z', 'label': '13:00-14:00', 'count': 11419, 'dose_one': 8377, 'dose_two': 3042}, {'ts': '2021-03-08T04:00:00.000Z', 'timestamps': '2021-03-08T10:00:00.000Z', 'label': '10:00-11:00', 'count': 1894, 'dose_one': 1424, 'dose_two': 470}, {'ts': '2021-03-08T11:00:00.000Z', 'timestamps': '2021-03-08T17:00:00.000Z', 'label': '17:00-18:00', 'count': 5762, 'dose_one': 3808, 'dose_two': 1954}, {'ts': '2021-03-08T05:00:00.000Z', 'timestamps': '2021-03-08T11:00:00.000Z', 'label': '11:00-12:00', 'count': 4598, 'dose_one': 3435, 'dose_two': 1163}, {'ts': '2021-03-08T03:00:00.000Z', 'timestamps': '2021-03-08T09:00:00.000Z', 'label': '09:00-10:00', 'count': 182, 'dose_one': 135, 'dose_two': 47}, {'ts': '2021-03-08T14:00:00.000Z', 'timestamps': '2021-03-08T20:00:00.000Z', 'label': '20:00-21:00', 'count': 670, 'dose_one': 352, 'dose_two': 318}, {'ts': '2021-03-08T16:00:00.000Z', 'timestamps': '2021-03-08T22:00:00.000Z', 'label': '22:00-23:00', 'count': 104, 'dose_one': 101, 'dose_two': 3}, {'ts': '2021-03-08T15:00:00.000Z', 'timestamps': '2021-03-08T21:00:00.000Z', 'label': '21:00-22:00', 'count': 62, 'dose_one': 44, 'dose_two': 18}], 'last7DaysRegistration': [], 'last7DaysVaccination': [{'vaccine_date': '2021-03-01', 'count': 4674, 'dose_one': 3779, 'dose_two': 895}, {'vaccine_date': '2021-03-02', 'count': 9170, 'dose_one': 7187, 'dose_two': 1983}, {'vaccine_date': '2021-03-03', 'count': 13383, 'dose_one': 10717, 'dose_two': 2666}, {'vaccine_date': '2021-03-04', 'count': 14097, 'dose_one': 10925, 'dose_two': 3172}, {'vaccine_date': '2021-03-05', 'count': 19882, 'dose_one': 14151, 'dose_two': 5731}, {'vaccine_date': '2021-03-06', 'count': 23890, 'dose_one': 15269, 'dose_two': 8621}, {'vaccine_date': '2021-03-07', 'count': 2131, 'dose_one': 1308, 'dose_two': 823}], 'getBeneficiariesGroupBy': [{'district_id': 264, 'id': 264, 'title': 'Belgaum', 'district_name': 'Belgaum', 'total': 48592, 'partial_vaccinated': 27585, 'totally_vaccinated': 21007}, {'district_id': 265, 'id': 265, 'title': 'Bangalore Urban', 'district_name': 'Bangalore Urban', 'total': 35074, 'partial_vaccinated': 26125, 'totally_vaccinated': 8949}, {'district_id': 266, 'id': 266, 'title': 'Mysore', 'district_name': 'Mysore', 'total': 42005, 'partial_vaccinated': 26439, 'totally_vaccinated': 15566}, {'district_id': 267, 'id': 267, 'title': 'Gulbarga', 'district_name': 'Gulbarga', 'total': 19590, 'partial_vaccinated': 13158, 'totally_vaccinated': 6432}, {'district_i ...

# %%
df
# Out:
#          index  total_sites  govt_sites  pvt_sites
# 0   2021-03-08         2691        2331        360
# 1   2021-03-09         1144         760        384
# 2   2021-03-10         2887        2450        437
# 3   2021-03-11          624         307        317
# 4   2021-03-12         3094        2619        475
# 5   2021-03-13         1747        1307        440
# 6   2021-03-14          693         495        198
# 7   2021-03-15         3284        2764        520
# 8   2021-03-16         2057        1529        528
# 9   2021-03-17         3444        2894        550
# 10  2021-03-18         1958        1409        549
# 11  2021-03-19         3548        2970        578
# 12  2021-03-20         3671        3102        569
# 13  2021-03-21         1097         869        228
# 14  2021-03-22         3936        3337        599
# 15  2021-03-23         2994        2402        592
# 16  2021-03-24         4255        3638        617
# 17  2021-03-25         2592        1985        607
# 18  2021-03-26         4394        3781        613
# 19  2021-03-27         3717        3131        586
# 20  2021-03-28         1768        1511        257
# 21  2021-03-29         4326        3714        612
# 22  2021-03-30         3730        3093        637
# 23  2021-03-31         4529        3871        658
# 24  2021-04-01         3875        3260        615
# 25  2021-04-02         4568        3982        586
# 26  2021-04-03         5431        4858        573
# 27  2021-04-04         4510        4074        436
# 28  2021-04-05         6103        5434        669
# 29  2021-04-06         6304        5605        699
# 30  2021-04-07         6734        6069        665
# 31  2021-04-08         6527        5813        714
# 32  2021-04-09         7338        6608        730
# 33  2021-04-10         6838        6184        654
# 34  2021-04-11         6163        5644        519
# 35  2021-04-12         6980        6255        725
# 36  2021-04-13         6051        5463        588
# 37  2021-04-14         6246        5560        686
# 38  2021-04-15         6219        5495        724
# 39  2021-04-16         6538        5808        730
# 40  2021-04-17         6682        6041        641
# 41  2021-04-18         6265        5722        543
# 42  2021-04-19         7256        6530        726
# 43  2021-04-20         7385        6647        738
# 44  2021-04-21         6960        6232        728
# 45  2021-04-22         7148        6399        749

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
plt.plot(df['total_sites'], label = 'Total Sites')
plt.plot(df['govt_sites'], label = 'Total Sites')
plt.plot(df['pvt_sites'], label = 'Total Sites')
plt.legend()
