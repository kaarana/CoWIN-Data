# %% [markdown]
# ### Importing Libraries

# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
from fpdf import FPDF
import dataframe_image as dfi

# %%
directory = 'data'
def get_state_data(state_code): 
    ls = []
    ls_for_index = []
    for index, filename in enumerate(os.scandir(directory)):
        if filename.is_file():
            if str(filename.path).startswith(f'data\CoWIN_IN_{state_code}_2021'):
                f = open(filename.path,)
                data = json.load(f)
                ls.append(data)
                ls_for_index.append(' '.join(list(filename.path.split('\\')[1].split('.')[0].split(f'{state_code}_')[1].split('-'))))
    return ls, ls_for_index

# %%
def get_state_dfs(state_code):
    ls, ls_for_index = get_state_data(state_code)
    df = pd.DataFrame() 
    df['date-index'] = ls_for_index
    df['date-index'] =  pd.to_datetime(df['date-index'], format='%Y %m %d')
    df.reset_index().set_index('date-index')
    ls_total_sites = []
    for i in range(len(ls)):
        try:
            ls_total_sites.append(ls[i]['topBlock']['sites']['total'])
        except:
            ls_total_sites.append(None)
    df['total_sites'] = ls_total_sites

    ls_govt_sites = []
    for i in range(len(ls)):
        try:
            ls_govt_sites.append(ls[i]['topBlock']['sites']['govt'])
        except:
            ls_govt_sites.append(None)
    df['govt_sites'] = ls_govt_sites

    ls_pvt_sites = []
    for i in range(len(ls)):
        try:
            ls_pvt_sites.append(ls[i]['topBlock']['sites']['pvt'])
        except:
            ls_pvt_sites.append(None)
    df['pvt_sites'] = ls_pvt_sites
    df = df.reset_index(drop=True)

    ls_total_sessions = []
    for i in range(len(ls)):
        try:
            ls_total_sessions.append(ls[i]['topBlock']['sessions']['total'])
        except:
            ls_total_sessions.append(None)
    df['total_sessions'] = ls_total_sessions

    ls_govt_sessions = []
    for i in range(len(ls)):
        try:
            ls_govt_sessions.append(ls[i]['topBlock']['sessions']['govt'])
        except:
            ls_govt_sessions.append(None)
    df['govt_sessions'] = ls_govt_sessions

    ls_pvt_sessions = []
    for i in range(len(ls)):
        try:
            ls_pvt_sessions.append(ls[i]['topBlock']['sessions']['pvt'])
        except:
            ls_pvt_sessions.append(None)
    df['pvt_sessions'] = ls_pvt_sessions

    ls_total_vaccine_cumulative = []
    for i in range(len(ls)):
        try:
            ls_total_vaccine_cumulative.append(ls[i]['topBlock']['vaccination']['total'])
        except:
            ls_total_vaccine_cumulative.append(None)
    df['total_vacc_cumulative'] = ls_total_vaccine_cumulative

    ls_vac_male = []
    for i in range(len(ls)):
        try:
            ls_vac_male.append(ls[i]['topBlock']['vaccination']['male'])
        except:
            ls_vac_male.append(None)
    df['vacc_male'] = ls_vac_male

    ls_vac_female = []
    for i in range(len(ls)):
        try:
            ls_vac_female.append(ls[i]['topBlock']['vaccination']['female'])
        except:
            ls_vac_female.append(None)
    df['vacc_female'] = ls_vac_female
    
    ls_vac_others = []
    for i in range(len(ls)):
        try:
            ls_vac_others.append(ls[i]['topBlock']['vaccination']['others'])
        except:
            ls_vac_others.append(None)
    df['vacc_others'] = ls_vac_others

    ls_covishield = []
    for i in range(len(ls)):
        try:
            ls_covishield.append(ls[i]['topBlock']['vaccination']['covishield'])
        except:
            ls_covishield.append(None)
    df['covishield'] = ls_covishield
    
    ls_covaxin = []
    for i in range(len(ls)):
        try:
            ls_covaxin.append(ls[i]['topBlock']['vaccination']['covaxin'])
        except:
            ls_covaxin.append(None)
    df['covaxin'] = ls_covaxin
    
    ls_today = []
    for i in range(len(ls)):
        try:
            ls_today.append(ls[i]['topBlock']['vaccination']['today'])
        except:
            ls_today.append(None)
    df['today'] = ls_today
    
    ls_total_dose_1 = []
    for i in range(len(ls)):
        try:
            ls_total_dose_1.append(ls[i]['topBlock']['vaccination']['tot_dose_1'])
        except:
            ls_total_dose_1.append(None)
    df['total_dose_1'] = ls_total_dose_1
    
    ls_total_dose_2 = []
    for i in range(len(ls)):
        try:
            ls_total_dose_2.append(ls[i]['topBlock']['vaccination']['tot_dose_2'])
        except:
            ls_total_dose_2.append(None)
    df['total_dose_2'] = ls_total_dose_2
    
    ls_total_doses = []
    for i in range(len(ls)):
        try:
            ls_total_doses.append(ls[i]['topBlock']['vaccination']['total_doses'])
        except:
            ls_total_doses.append(None)
    df['total_doses'] = ls_total_doses
    
    ls_district_id = []
    ls_id = []
    ls_title = []
    ls_district_name = []
    ls_vacc_district = []
    ls_total_vacc_district = []
    ls_partial_vacc_district = []
    df_district = pd.DataFrame() 
    for i in range(len(ls)):
        for j in range(len((ls[i]['getBeneficiariesGroupBy']))):
            try:
                ls_district_id.append(ls[i]['getBeneficiariesGroupBy'][j]['district_id'])
            except:
                ls_district_id.append(None)
            try:
                ls_id.append(ls[i]['getBeneficiariesGroupBy'][j]['id'])
            except:
                ls_id.append(None)
            try:
                ls_title.append(ls[i]['getBeneficiariesGroupBy'][j]['title'])
            except:
                ls_title.append(None)   
            try:
                ls_district_name.append(ls[i]['getBeneficiariesGroupBy'][j]['district_name'])
            except:
                ls_district_name.append(None)   
            try:
                ls_vacc_district.append(ls[i]['getBeneficiariesGroupBy'][j]['total'])
            except:
                ls_vacc_district.append(None)   
            try:
                ls_total_vacc_district.append(ls[i]['getBeneficiariesGroupBy'][j]['totally_vaccinated'])
            except:
                ls_total_vacc_district.append(None)   
            try:
                ls_partial_vacc_district.append(ls[i]['getBeneficiariesGroupBy'][j]['partial_vaccinated'])
            except:
                ls_partial_vacc_district.append(None)  
    df_district['district_id'] = ls_district_id
    df_district['id'] = ls_id
    df_district['title'] = ls_title
    df_district['district_name'] = ls_district_name
    df_district['vaccinatated_in_district_partial_and_total'] = ls_vacc_district
    df_district['vaccinatated_in_district_total'] = ls_total_vacc_district
    df_district['vaccinatated_in_district_partial'] = ls_partial_vacc_district
    return df, df_district

# %%
df, df_district = get_state_dfs(16)
ls, ls_index = get_state_data(16)

# %%
def get_district_changes(district_code, state_code):
    df, df_district = get_state_dfs(state_code)
    df_some_district = df_district.loc[df_district['district_id'] == district_code]
    dfi.export(df_some_district,f"datatable_{state_code}_{district_code}.png")
    return df_some_district

def plot_district_changes(district_code, state_code):
    plt.figure(figsize=(20,10))
    df_some_district = get_district_changes(district_code, state_code)
    plt.plot(df_some_district['vaccinatated_in_district_partial_and_total'], label = 'All Vaccinations')
    plt.plot(df_some_district['vaccinatated_in_district_total'], label = 'Completed Vaccinations')
    plt.plot(df_some_district['vaccinatated_in_district_partial'], label = 'Partial Vaccinations')
    plt.legend()
    plt.title(f'Vaccination Curves for District Number {district_code}')
    plt.savefig(f'district_changes_{district_code}_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)
    
    
def plot_genderwise_state(state_code):
    df, df_district = get_state_dfs(state_code)
    plt.figure(figsize=(20,10))
    plt.plot(df['vacc_male'], label = 'Male Vaccination')
    plt.plot(df['vacc_female'], label = 'Female Vaccinations')
    plt.plot(df['vacc_others'], label = 'Other Vaccinations')
    plt.title(f'Gender Wise Stats for State:{state_code}')
    plt.legend()
    plt.savefig(f'genderwise_state_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)

def plot_dosewise_state(state_code):
    df, df_district = get_state_dfs(state_code)
    plt.figure(figsize=(20,10))
    plt.plot(df['total_dose_1'], label = 'Total Dose 1')
    plt.plot(df['total_dose_2'], label = 'Total Dose 2')
    plt.plot(df['total_doses'], label = 'Total Doses')
    plt.legend()
    plt.title(f'Dose Wise Stats for State:{state_code}')
    plt.savefig(f'dosewise_state_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)
    
def plot_site_stats(state_code):
    plt.figure(figsize=(20,10))
    df, df_district = get_state_dfs(state_code)
    plt.plot(df['total_sites'], label = 'Total Sites')
    plt.plot(df['govt_sites'], label = 'Government Sites')
    plt.plot(df['pvt_sites'], label = 'Private Sites')
    plt.legend()
    plt.title(f'Site wise Stats for State:{state_code}')
    plt.savefig(f'site_stats_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)
    
def plot_diff_vacc(state_code):
    plt.figure(figsize=(20,10))
    df, df_district = get_state_dfs(state_code)
    plt.plot(df['covaxin'], label = 'Covaxin')
    plt.plot(df['covishield'], label = 'Covishield')
    plt.legend()
    plt.title(f'Different Kinds of Vaccine Stats for State:{state_code}')
    plt.savefig(f'diff_vaccine_stats_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)
    
plot_diff_vacc(16)

# %%
ls
# Out:
# [{'topBlock': {'sites': {'total': 2691,
#     'govt': 2331,
#     'pvt': 360,
#     'today': None},
#    'sessions': {'total': 331650, 'govt': 274450, 'pvt': 57200, 'today': None},
#    'registration': {'total': None,
#     'male': None,
#     'female': None,
#     'others': None,
#     'today': None},
#    'vaccination': {'total': 743007,
#     'male': 341256,
#     'female': 401647,
#     'others': 104,
#     'covishield': 736102,
#     'covaxin': 6852,
#     'today': 63344}},
#   'vaccinationDoneByTime': [{'ts': '2021-03-08T06:00:00.000Z',
#     'timestamps': '2021-03-08T12:00:00.000Z',
#     'label': '12:00-13:00',
#     'count': 8364,
#     'dose_one': 6263,
#     'dose_two': 2101},
#    {'ts': '2021-03-08T08:00:00.000Z',
#     'timestamps': '2021-03-08T14:00:00.000Z',
#     'label': '14:00-15:00',
#     'count': 9066,
#     'dose_one': 6539,
#     'dose_two': 2527},
#    {'ts': '2021-03-08T10:00:00.000Z',
#     'timestamps': '2021-03-08T16:00:00.000Z',
#     'label': '16:00-17:00',
#     'count': 9476,
#     'dose_one': 6036,
#     'dose_two': 3440},
#    {'ts': '2021-03-08T12:00:00.000Z',
#     'timestamps': '2021-03-08T18:00:00.000Z',
#     'label': '18:00-19:00',
#     'count': 1746,
#     'dose_one': 1160,
#     'dose_two': 586},
#    {'ts': '2021-03-08T13:00:00.000Z',
#     'timestamps': '2021-03-08T19:00:00.000Z',
#     'label': '19:00-20:00',
#     'count': 769,
#     'dose_one': 441,
#     'dose_two': 328},
#    {'ts': '2021-03-08T17:00:00.000Z',
#     'timestamps': '2021-03-08T23:00:00.000Z',
#     'label': '23:00-00:00',
#     'count': 42,
#     'dose_one': 26,
#     'dose_two': 16},
#    {'ts': '2021-03-08T09:00:00.000Z',
#     'timestamps': '2021-03-08T15:00:00.000Z',
#     'label': '15:00-16:00',
#     'count': 9157,
#     'dose_one': 5893,
#     'dose_two': 3264},
#    {'ts': '2021-03-08T07:00:00.000Z',
#     'timestamps': '2021-03-08T13:00:00.000Z',
#     'label': '13:00-14:00',
#     'count': 11419,
#     'dose_one': 8377,
#     'dose_two': 3042},
#    {'ts': '2021-03-08T04:00:00.000Z',
#     'timestamps': '2021-03-08T10:00:00.000Z',
#     'label': '10:00-11:00',
#     'count': 1894,
#     'dose_one': 1424,
#     'dose_two': 470},
#    {'ts': '2021-03-08T11:00:00.000Z',
#     'timestamps': '2021-03-08T17:00:00.000Z',
#     'label': '17:00-18:00',
#     'count': 5762,
#     'dose_one': 3808,
#     'dose_two': 1954},
#    {'ts': '2021-03-08T05:00:00.000Z',
#     'timestamps': '2021-03-08T11:00:00.000Z',
#     'label': '11:00-12:00',
#     'count': 4598,
#     'dose_one': 3435,
#     'dose_two': 1163},
#    {'ts': '2021-03-08T03:00:00.000Z',
#     'timestamps': '2021-03-08T09:00:00.000Z',
#     'label': '09:00-10:00',
#     'count': 182,
#     'dose_one': 135,
#     'dose_two': 47},
#    {'ts': '2021-03-08T14:00:00.000Z',
#     'timestamps': '2021-03-08T20:00:00.000Z',
#     'label': '20:00-21:00',
#     'count': 670,
#     'dose_one': 352,
#     'dose_two': 318},
#    {'ts': '2021-03-08T16:00:00.000Z',
#     'timestamps': '2021-03-08T22:00:00.000Z',
#     'label': '22:00-23:00',
#     'count': 104,
#     'dose_one': 101,
#     'dose_two': 3},
#    {'ts': '2021-03-08T15:00:00.000Z',
#     'timestamps': '2021-03-08T21:00:00.000Z',
#     'label': '21:00-22:00',
#     'count': 62,
#     'dose_one': 44,
#     'dose_two': 18}],
#   'last7DaysRegistration': [],
#   'last7DaysVaccination': [{'vaccine_date': '2021-03-01',
#     'count': 4674,
#     'dose_one': 3779,
#     'dose_two': 895},
#    {'vaccine_date': '2021-03-02',
#     'count': 9170,
#     'dose_one': 7187,
#     'dose_two': 1983},
#    {'vaccine_date': '2021-03-03',
#     'count': 13383,
#     'dose_one': 10717,
#     'dose_two': 2666},
#    {'vaccine_date': '2021-03-04',
#     'count': 14097,
#     'dose_one': 10925,
#     'dose_two': 3172},
#    {'vaccine_date': '2021-03-05',
#     'count': 19882,
#     'dose_one': 14151,
#     'dose_two': 5731},
#    {'vaccine_date': '2021-03-06',
#     'count': 23890,
#     'dose_one': 15269,
#     'dose_two': 8621},
#    {'vaccine_date': '2021-03-07',
#     'count': 2131,
#     'dose_one': 1308,
#     'dose_two': 823}],
#   'getBeneficiariesGroupBy': [{'district_id': 264,
#     'id': 264,
#     'title': 'Belgaum',
#     'district_name': 'Belgaum',
#     'total': 48592,
#     'partial_vaccinated': 27585,
#     'totally_vaccinated': 21007},
#    {'district_id': 265,
#     'id': 265,
#     'title': 'Bangalore Urban',
#     'district_name': 'Bangalore Urban',
#     'total': 35074,
#     'partial_vaccinated': 26125,
#     'totally_vaccinated': 8949},
#    {'district_id': 266,
#     'id': 266,
#     'title': 'Mysore',
#     'district_name': 'Mysore',
#     'total': 42005,
#     'partial_vaccinated': 26439,
#     'totally_vaccinated': 15566},
#    {'district_id': 267,
#     'id': 267,
#     'title': 'Gulbarga',
#     'district_name': 'Gulbarga',
#     'total': 19590,
#     'partial_vaccinated': 13158,
#     'totally_vaccinated': 6432},
#    {'district_id': 268,
#     'id': 268,
#     'title': 'Chitradurga',
#     'district_name': 'Chitradurga',
#     'total': 16779,
#     'partial_vaccinated': 9079,
#     'totally_vaccinated': 7700},
#    {'district_id': 269,
#     'id': 269,
#     'title': 'Dakshina Kannada',
#     'district_name': 'Dakshina Kannada',
#     'total': 42138,
#     'partial_vaccinated': 25267,
#     'totally_vaccinated': 16871},
#    {'district_id': 270,
#     'id': 270,
#     'title': 'Bagalkot',
#     'district_name': 'Bagalkot',
#     'total': 15694,
#     'partial_vaccinated': 11385,
#     'totally_vaccinated': 4309},
#    {'district_id': 271,
#     'id': 271,
#     'title': 'Chamarajanagar',
#     'district_name': 'Chamarajanagar',
#     'total': 8079,
#     'partial_vaccinated': 5339,
#     'totally_vaccinated': 2740},
#    {'district_id': 272,
#     'id': 272,
#     'title': 'Bidar',
#     'district_name': 'Bidar',
#     'total': 12470,
#     'partial_vaccinated': 8364,
#     'totally_vaccinated': 4106},
#    {'district_id': 273,
#     'id': 273,
#     'title': 'Chikamagalur',
#     'district_name': 'Chikamagalur',
#     'total': 14334,
#     'partial_vaccinated': 10027,
#     'totally_vaccinated': 4307},
#    {'district_id': 274,
#     'id': 274,
#     'title': 'Bellary',
#     'district_name': 'Bellary',
#     'total': 23493,
#     'partial_vaccinated': 15745,
#     'totally_vaccinated': 7748},
#    {'district_id': 275,
#     'id': 275,
#     'title': 'Davanagere',
#     'district_name': 'Davanagere',
#     'total': 16923,
#     'partial_vaccinated': 11003,
#     'totally_vaccinated': 5920},
#    {'district_id': 276,
#     'id': 276,
#     'title': 'Bangalore Rural',
#     'district_name': 'Bangalore Rural',
#     'total': 14509,
#     'partial_vaccinated': 10436,
#     'totally_vaccinated': 4073},
#    {'district_id': 277,
#     'id': 277,
#     'title': 'Kolar',
#     'district_name': 'Kolar',
#     'total': 16511,
#     'partial_vaccinated': 10196,
#     'totally_vaccinated': 6315},
#    {'district_id': 278,
#     'id': 278,
#     'title': 'Dharwad',
#     'district_name': 'Dharwad',
#     'total': 24190,
#     'partial_vaccinated': 15138,
#     'totally_vaccinated': 9052},
#    {'district_id': 279,
#     'id': 279,
#     'title': 'Haveri',
#     'district_name': 'Haveri',
#     'total': 10089,
#     'partial_vaccinated': 6550,
#     'totally_vaccinated': 3539},
#    {'district_id': 280,
#     'id': 280,
#     'title': 'Gadag',
#     'district_name': 'Gadag',
#     'total': 12350,
#     'partial_vaccinated': 9052,
#     'totally_vaccinated': 3298},
#    {'district_id': 281,
#     'id': 281,
#     'title': 'Uttar Kannada',
#     'district_name': 'Uttar Kannada',
#     'total': 20863,
#     'partial_vaccinated': 11411,
#     'totally_vaccinated': 9452},
#    {'district_id': 282,
#     'id': 282,
#     'title': 'Koppal',
#     'district_name': 'Koppal',
#     'total': 11714,
#     'partial_vaccinated': 9037,
#     'totally_vaccinated': 2677},
#    {'district_id': 283,
#     'id': 283,
#     'title': 'Kodagu',
#     'district_name': 'Kodagu',
#     'total': 8101,
#     'partial_vaccinated': 4304,
#     'totally_vaccinated': 3797},
#    {'district_id': 284,
#     'id': 284,
#     'title': 'Raichur',
#     'district_name': 'Raichur',
#     'total': 16401,
#     'partial_vaccinated': 9758,
#     'totally_vaccinated': 6643},
#    {'district_id': 285,
#     'id': 285,
#     'title': 'Yadgir',
#     'district_name': 'Yadgir',
#     'total': 6379,
#     'partial_vaccinated': 3914,
#     'totally_vaccinated': 2465},
#    {'district_id': 286,
#     'id': 286,
#     'title': 'Udupi',
#     'district_name': 'Udupi',
#     'total': 25114,
#     'partial_vaccinated': 13715,
#     'totally_vaccinated': 11399},
#    {'district_id': 287,
#     'id': 287,
#     'title': 'Shimoga',
#     'district_name': 'Shimoga',
#     'total': 22670,
#     'partial_vaccinated': 14238,
#     'totally_vaccinated': 8432},
#    {'district_id': 288,
#     'id': 288,
#     'title': 'Tumkur',
#     'district_name': 'Tumkur',
#     'total': 32065,
#     'partial_vaccinated': 17937,
#     'totally_vaccinated': 14128},
#    {'district_id': 289,
#     'id': 289,
#     'title': 'Hassan',
#     'district_name': 'Hassan',
#     'total': 20940,
#     'partial_vaccinated': 14132,
#     'totally_vaccinated': 6808},
#    {'district_id': 290,
#     'id': 290,
#     'title': 'Mandya',
#     'district_name': 'Mandya',
#     'total': 19897,
#     'partial_vaccinated': 11991,
#     'totally_vaccinated': 7906},
#    {'district_id': 291,
#     'id': 291,
#     'title': 'Chikkaballapur',
#     'district_name': 'Chikkaballapur',
#     'total': 12479,
#     'partial_vaccinated': 6850,
#     'totally_vaccinated': 5629},
#    {'district_id': 292,
#     'id': 292,
#     'title': 'Ramanagara',
#     'district_name': 'Ramanagara',
#     'total': 11158,
#     'partial_vaccinated': 6479,
#     'totally_vaccinated': 4679},
#    {'district_id': 293,
#     'id': 293,
#     'title': 'Vijayapura',
#     'district_name': 'Vijayapura',
#     'total': 18225,
#     'partial_vaccinated': 12615,
#     'totally_vaccinated': 5610},
#    {'district_id': 294,
#     'id': 294,
#     'title': 'BBMP',
#     'district_name': 'BBMP',
#     'total': 140641,
#     'partial_vaccinated': 98300,
#     'totally_vaccinated': 42341}],
#   'reportFor': 'State : 16 | 2021-03-08',
#   'timestamp': '2021-03-08 18:00:54'},
#  {'topBlock': {'sites': {'total': 1144,
#     'govt': 760,
#     'pvt': 384,
#     'today': None},
#    'sessions': {'total': 163150, 'govt': 100200, 'pvt': 62950, 'today': None},
#    'registration': {'total': None,
#     'male': None,
#     'female': None,
#     'others': None,
#     'today': None},
#    'vaccination': {'total': 788948,
#     'male': 364689,
#     'female': 424140,
#     'others': 119,
#     'covishield': 781675,
#     'covaxin': 7220,
#     'today': 45935,
#     'tot_dose_1': 511728,
#     'tot_dose_2': 277220,
#     'total_doses': 1066168}},
#   'vaccinationDoneByTime': [{'ts': '2021-03-09T09:00:00.000Z',
#     'timestamps': '2021-03-09T15:00:00.000Z',
#     'label': '15:00-16:00',
#     'count': 6126,
#     'dose_one': 4013,
#     'dose_two': 2113},
#    {'ts': '2021-03-09T07:00:00.000Z',
#     'timestamps': '2021-03-09T13:00:00.000Z',
#     'label': '13:00-14:00',
#     'count': 7279,
#     'dose_one': 5577,
#     'dose_two': 1702},
#    {'ts': '2021-03-09T10:00:00.000Z',
#     'timestamps': '2021-03-09T16:00:00.000Z',
#     'label': '16:00-17:00',
#     'count': 6861,
#     'dose_one': 4597,
#     'dose_two': 2264},
#    {'ts': '2021-03-09T06:00:00.000Z',
#     'timestamps': '2021-03-09T12:00:00.000Z',
#     'label': '12:00-13:00',
#     'count': 8046,
#     'dose_one': 6314,
#     'dose_two': 1732},
#    {'ts': '2021-03-09T08:00:00.000Z',
#     'timestamps': '2021-03-09T14:00:00.000Z',
#     'label': '14:00-15:00',
#     'count': 4923,
#     'dose_one': 3689,
#     'dose_two': 1234},
#    {'ts': '2021-03-09T04:00:00.000Z',
#     'timestamps': '2021-03-09T10:00:00.000Z',
#     'label': '10:00-11:00',
#     'count': 2123,
#     'dose_one': 1565,
#     'dose_two': 558},
#    {'ts': '2021-03-09T13:00:00.000Z',
#     'timestamps': '2021-03-09T19:00:00.000Z',
#     'label': '19:00-20:00',
#     'count': 433,
#     'dose_one': 327,
#     'dose_two': 106},
#    {'ts': '2021-03-09T11:00:00.000Z',
#     'timestamps': '2021-03-09T17:00:00.000Z',
#     'label': '17:00-18:00',
#     'count': 3160,
#     'dose_one': 1984,
#     'dose_two': 1176},
#    {'ts': '2021-03-09T15:00:00.000Z',
#     'timestamps': '2021-03-09T21:00:00.000Z',
#     'label': '21:00-22:00',
#     'count': 7,
#     'dose_one': 6,
#     'dose_two': 1},
#    {'ts': '2021-03-09T05:00:00.000Z',
#     'timestamps': '2021-03-09T11:00:00.000Z',
#     'label': '11:00-12:00',
#     'count': 5742,
#     'dose_one': 4506,
#     'dose_two': 1236},
#    {'ts': '2021-03-09T03:00:00.000Z',
#     'timestamps': '2021-03-09T09:00:00.000Z',
#     'label': '09:00-10:00',
#     'count': 180,
#     'dose_one': 148,
#     'dose_two': 32},
#    {'ts': '2021-03-09T12:00:00.000Z',
#     'timestamps': '2021-03-09T18:00:00.000Z',
#     'label': '18:00-19:00',
#     'count': 847,
#     'dose_one': 647,
#     'dose_two': 200},
#    {'ts': '2021-03-09T14:00:00.000Z',
#     'timestamps': '2021-03-09T20:00:00.000Z',
#     'label': '20:00-21:00',
#     'count': 93,
#     'dose_one': 71,
#     'dose_two': 22},
#    {'ts': '2021-03-09T16:00:00.000Z',
#     'timestamps': '2021-03-09T22:00:00.000Z',
#     'label': '22:00-23:00',
#     'count': 1,
#     'dose_one': 0,
#     'dose_two': 1},
#    {'ts': '2021-03-09T17:00:00.000Z',
#     'timestamps': '2021-03-09T23:00:00.000Z',
#     'label': '23:00-00:00',
#     'count': 86,
#     'dose_one': 2,
#     'dose_two': 84}],
#   'last7DaysRegistration': [],
#   'last7DaysVaccination': [{'vaccine_date': '2021-03-02',
#     'count': 9170,
#     'dose_one': 7187,
#     'dose_two': 1983},
#    {'vaccine_date': '2021-03-03',
#     'count': 13383,
#     'dose_one': 10717,
#     'dose_two': 2666},
#    {'vaccine_date': '2021-03-04',
#     'count': 14097,
#     'dose_one': 10925,
#     'dose_two': 3172},
#    {'vaccine_date': '2021-03-05',
#     'count': 19882,
#     'dose_one': 14151,
#     'dose_two': 5731},
#    {'vaccine_date': '2021-03-06',
#     'count': 23890,
#     'dose_one': 15269,
#     'dose_two': 8621},
#    {'vaccine_date': '2021-03-07',
#     'count': 2131,
#     'dose_one': 1308,
#     'dose_two': 823},
#    {'vaccine_date': '2021-03-08',
#     'count': 63350,
#     'dose_one': 44095,
#     'dose_two': 19255}],
#   'getBeneficiariesGroupBy': [{'district_id': 264,
#     'id': 264,
#     'title': 'Belgaum',
#     'district_name': 'Belgaum',
#     'total': 50802,
#     'partial_vaccinated': 29173,
#     'totally_vaccinated': 21629},
#    {'district_id': 265,
#     'id': 265,
#     'title': 'Bangalore Urban',
#     'district_name': 'Bangalore Urban',
#     'total': 36523,
#     'partial_vaccinated': 27058,
#     'totally_vaccinated': 9465},
#    {'district_id': 266,
#     'id': 266,
#     'title': 'Mysore',
#     'district_name': 'Mysore',
#     'total': 44414,
#     'partial_vaccinated': 28118,
#     'totally_vaccinated': 16296},
#    {'district_id': 267,
#     'id': 267,
#     'title': 'Gulbarga',
#     'district_name': 'Gulbarga',
#     'total': 20776,
#     'partial_vaccinated': 14055,
#     'totally_vaccinated': 6721},
#    {'district_id': 268,
#     'id': 268,
#     'title': 'Chitradurga',
#     'district_name': 'Chitradurga',
#     'total': 17259,
#     'partial_vaccinated': 9517,
#     'totally_vaccinated': 7742},
#    {'district_id': 269,
#     'id': 269,
#     'title': 'Dakshina Kannada',
#     'district_name': 'Dakshina Kannada',
#     'total': 44259,
#     'partial_vaccinated': 26129,
#     'totally_vaccinated': 18130},
#    {'district_id': 270,
#     'id': 270,
#     'title': 'Bagalkot',
#     'district_name': 'Bagalkot',
#     'total': 16419,
#     'partial_vaccinated': 11767,
#     'totally_vaccinated': 4652},
#    {'district_id': 271,
#     'id': 271,
#     'title': 'Chamarajanagar',
#     'district_name': 'Chamarajanagar',
#     'total': 8297,
#     'partial_vaccinated': 5416,
#     'totally_vaccinated': 2881},
#    {'district_id': 272,
#     'id': 272,
#     'title': 'Bidar',
#     'district_name': 'Bidar',
#     'total': 13008,
#     'partial_vaccinated': 8773,
#     'totally_vaccinated': 4235},
#    {'district_id': 273,
#     'id': 273,
#     'title': 'Chikamagalur',
#     'district_name': 'Chikamagalur',
#     'total': 15822,
#     'partial_vaccinated': 11016,
#     'totally_vaccinated': 4806},
#    {'district_id': 274,
#     'id': 274,
#     'title': 'Bellary',
#     'district_name': 'Bellary',
#     'total': 24723,
#     'partial_vaccinated': 16477,
#     'totally_vaccinated': 8246},
#    {'district_id': 275,
#     'id': 275,
#     'title': 'Davanagere',
#     'district_name': 'Davanagere',
#     'total': 17677,
#     'partial_vaccinated': 11421,
#     'totally_vaccinated': 6256},
#    {'district_id': 276,
#     'id': 276,
#     'title': 'Bangalore Rural',
#     'district_name': 'Bangalore Rural',
#     'total': 15291,
#     'partial_vaccinated': 11103,
#     'totally_vaccinated': 4188},
#    {'district_id': 277,
#     'id': 277,
#     'title': 'Kolar',
#     'district_name': 'Kolar',
#     'total': 17121,
#     'partial_vaccinated': 10665,
#     'totally_vaccinated': 6456},
#    {'district_id': 278,
#     'id': 278,
#     'title': 'Dharwad',
#     'district_name': 'Dharwad',
#     'total': 25229,
#     'partial_vaccinated': 15911,
#     'totally_vaccinated': 9318},
#    {'district_id': 279,
#     'id': 279,
#     'title': 'Haveri',
#     'district_name': 'Haveri',
#     'total': 10473,
#     'partial_vaccinated': 6799,
#     'totally_vaccinated': 3674},
#    {'district_id': 280,
#     'id': 280,
#     'title': 'Gadag',
#     'district_name': 'Gadag',
#     'total': 13447,
#     'partial_vaccinated': 9984,
#     'totally_vaccinated': 3463},
#    {'district_id': 281,
#     'id': 281,
#     'title': 'Uttar Kannada',
#     'district_name': 'Uttar Kannada',
#     'total': 21918,
#     'partial_vaccinated': 12360,
#     'totally_vaccinated': 9558},
#    {'district_id': 282,
#     'id': 282,
#     'title': 'Koppal',
#     'district_name': 'Koppal',
#     'total': 12015,
#     'partial_vaccinated': 9222,
#     'totally_vaccinated': 2793},
#    {'district_id': 283,
#     'id': 283,
#     'title': 'Kodagu',
#     'district_name': 'Kodagu',
#     'total': 8295,
#     'partial_vaccinated': 4437,
#     'totally_vaccinated': 3858},
#    {'district_id': 284,
#     'id': 284,
#     'title': 'Raichur',
#     'district_name': 'Raichur',
#     'total': 16949,
#     'partial_vaccinated': 10035,
#     'totally_vaccinated': 6914},
#    {'district_id': 285,
#     'id': 285,
#     'title': 'Yadgir',
#     'district_name': 'Yadgir',
#     'total': 6622,
#     'partial_vaccinated': 4039,
#     'totally_vaccinated': 2583},
#    {'district_id': 286,
#     'id': 286,
#     'title': 'Udupi',
#     'district_name': 'Udupi',
#     'total': 26468,
#     'partial_vaccinated': 14368,
#     'totally_vaccinated': 12100},
#    {'district_id': 287,
#     'id': 287,
#     'title': 'Shimoga',
#     'district_name': 'Shimoga',
#     'total': 23338,
#     'partial_vaccinated': 14655,
#     'totally_vaccinated': 8683},
#    {'district_id': 288,
#     'id': 288,
#     'title': 'Tumkur',
#     'district_name': 'Tumkur',
#     'total': 39765,
#     'partial_vaccinated': 25364,
#     'totally_vaccinated': 14401},
#    {'district_id': 289,
#     'id': 289,
#     'title': 'Hassan',
#     'district_name': 'Hassan',
#     'total': 21996,
#     'partial_vaccinated': 14675,
#     'totally_vaccinated': 7321},
#    {'district_id': 290,
#     'id': 290,
#     'title': 'Mandya',
#     'district_name': 'Mandya',
#     'total': 20577,
#     'partial_vaccinated': 12520,
#     'totally_vaccinated': 8057},
#    {'district_id': 291,
#     'id': 291,
#     'title': 'Chikkaballapur',
#     'district_name': 'Chikkaballapur',
#     'total': 12783,
#     'partial_vaccinated': 7096,
#     'totally_vaccinated': 5687},
#    {'district_id': 292,
#     'id': 292,
#     'title': 'Ramanagara',
#     'district_name': 'Ramanagara',
#     'total': 11423,
#     'partial_vaccinated': 6705,
#     'totally_vaccinated': 4718},
#    {'district_id': 293,
#     'id': 293,
#     'title': 'Vijayapura',
#     'district_name': 'Vijayapura',
#     'total': 18894,
#     'partial_vaccinated': 13148,
#     'totally_vaccinated': 5746},
#    {'district_id': 294,
#     'id': 294,
#     'title': 'BBMP',
#     'district_name': 'BBMP',
#     'total': 155654,
#     'partial_vaccinated': 109182,
#     'totally_vaccinated': 46472}],
#   'reportFor': 'State : 16 | 2021-03-09',
#   'timestamp': '2021-03-09 18:01:29'},
#  {'topBlock': {'sites': {'total': 2887,
#     'govt': 2450,
#     'pvt': 437,
#     'today': None},
#    'sessions': {'total': 359585, 'govt': 288325, 'pvt': 71260, 'today': None},
#    'registration': {'total': None,
#     'male': None,
#     'female': None,
#     'others': None,
#     'today': None},
#    'vaccination': {'total': 879486,
#     'male': 410153,
#     'female': 469202,
#     'others': 131,
#     'covishield': 872069,
#     'covaxin': 7364,
#     'today': 90538,
#     'tot_dose_1': 581668,
#     'tot_dose_2': 297818,
#     'total_doses': 1177304}},
#   'vaccinationDoneByTime': [{'ts': '2021-03-10T09:00:00.000Z',
#     'timestamps': '2021-03-10T15:00:00.000Z',
#     'label': '15:00-16:00',
#     'count': 11503,
#     'dose_one': 8249,
#     'dose_two': 3254},
#    {'ts': '2021-03-10T06:00:00.000Z',
#     'timestamps': '2021-03-10T12:00:00.000Z',
#     'label': '12:00-13:00',
#     'count': 17875,
#     'dose_one': 14584,
#     'dose_two': 3291},
#    {'ts': '2021-03-10T08:00:00.000Z',
#     'timestamps': '2021-03-10T14:00:00.000Z',
#     'label': '14:00-15:00',
#     'count': 10356,
#     'dose_one': 8267,
#     'dose_two': 2089},
#    {'ts': '2021-03-10T05:00:00.000Z',
#     'timestamps': '2021-03-10T11:00:00.000Z',
#     'label': '11:00-12:00',
#     'count': 11716,
#     'dose_one': 9583,
#     'dose_two': 2133},
#    {'ts': '2021-03-10T13:00:00.000Z',
#     'timestamps': '2021-03-10T19:00:00.000Z',
#     'label': '19:00-20:00',
#     'count': 672,
#     'dose_one': 506,
#     'dose_two': 166},
#    {'ts': '2021-03-10T07:00:00.000Z',
#     'timestamps': '2021-03-10T13:00:00.000Z',
#     'label': '13:00-14:00',
#     'count': 15821,
#     'dose_one': 12824,
#     'dose_two': 2997},
#    {'ts': '2021-03-10T04:00:00.000Z',
#     'timestamps': '2021-03-10T10:00:00.000Z',
#     'label': '10:00-11:00',
#     'count': 4043,
#     'dose_one': 3270,
#     'dose_two': 773},
#    {'ts': '2021-03-10T03:00:00.000Z',
#     'timestamps': '2021-03-10T09:00:00.000Z',
#     'label': '09:00-10:00',
#     'count': 344,
#     'dose_one': 272,
#     'dose_two': 72},
#    {'ts': '2021-03-10T16:00:00.000Z',
#     'timestamps': '2021-03-10T22:00:00.000Z',
#     'label': '22:00-23:00',
#     'count': 113,
#     'dose_one': 76,
#     'dose_two': 37},
#    {'ts': '2021-03-10T10:00:00.000Z',
#     'timestamps': '2021-03-10T16:00:00.000Z',
#     'label': '16:00-17:00',
#     'count': 11605,
#     'dose_one': 8002,
#     'dose_two': 3603},
#    {'ts': '2021-03-10T14:00:00.000Z',
#     'timestamps': '2021-03-10T20:00:00.000Z',
#     'label': '20:00-21:00',
#     'count': 423,
#     'dose_one': 223,
#     'dose_two': 200},
#    {'ts': '2021-03-10T11:00:00.000Z',
#     'timestamps': '2021-03-10T17:00:00.000Z',
#     'label': '17:00-18:00',
#     'count': 4744,
#     'dose_one': 3185,
#     'dose_two': 1559},
#    {'ts': '2021-03-10T15:00:00.000Z',
#     'timestamps': '2021-03-10T21:00:00.000Z',
#     'label': '21:00-22:00',
#     'count': 165,
#     'dose_one': 105,
#     'dose_two': 60},
#    {'ts': '2021-03-10T12:00:00.000Z',
#     'timestamps': '2021-03-10T18:00:00.000Z',
#     'label': '18:00-19:00',
#     'count': 1198,
#     'dose_one': 789,
#     'dose_two': 409},
#    {'ts': '2021-03-10T02:00:00.000Z',
#     'timestamps': '2021-03-10T08:00:00.000Z',
#     'label': '08:00-09:00',
#     'count': 9,
#     'dose_one': 7,
#     'dose_two': 2},
#    {'ts': '2021-03-10T17:00:00.000Z',
#     'timestamps': '2021-03-10T23:00:00.000Z',
#     'label': '23:00-00:00',
#     'count': 164,
#     'dose_one': 104,
#     'dose_two': 60}],
#   'last7DaysRegistration': [],
#   'last7DaysVaccination': [{'vaccine_date': '2021-03-03',
#     'count': 13383,
#     'dose_one': 10717,
#     'dose_two': 2666},
#    {'vaccine_date': '2021-03-04',
#     'count': 14097,
#     'dose_one': 10925,
#     'dose_two': 3172},
#    {'vaccine_date': '2021-03-05',
#     'count': 19882,
#     'dose_one': 14151,
#     'dose_two': 5731},
#    {'vaccine_date': '2021-03-06',
#     'count': 23890,
#     'dose_one': 15269,
#     'dose_two': 8621},
#    {'vaccine_date': '2021-03-07',
#     'count': 2131,
#     'dose_one': 1308,
#     'dose_two': 823},
#    {'vaccine_date': '2021-03-08',
#     'count': 63350,
#     'dose_one': 44095,
#     'dose_two': 19255},
#    {'vaccine_date': '2021-03-09',
#     'count': 45935,
#     'dose_one': 33482,
#     'dose_two': 12453}],
#   'getBeneficiariesGroupBy': [{'district_id': 264,
#     'id': 264,
#     'title': 'Belgaum',
#     'district_name': 'Belgaum',
#     'total': 55062,
#     'partial_vaccinated': 32356,
#     'totally_vaccinated': 22706},
#    {'district_id': 265,
#     'id': 265,
#     'title': 'Bangalore Urban',
#     'district_name': 'Bangalore Urban',
#     'total': 39034,
#     'partial_vaccinated': 28679,
#     'totally_vaccinated': 10355},
#    {'district_id': 266,
#     'id': 266,
#     'title': 'Mysore',
#     'district_name': 'Mysore',
#     'total': 48208,
#     'partial_vaccinated': 30935,
#     'totally_vaccinated': 17273},
#    {'district_id': 267,
#     'id': 267,
#     'title': 'Gulbarga',
#     'district_name': 'Gulbarga',
#     'total': 22393,
#     'partial_vaccinated': 15170,
#     'totally_vaccinated': 7223},
#    {'district_id': 268,
#     'id': 268,
#     'title': 'Chitradurga',
#     'district_name': 'Chitradurga',
#     'total': 19513,
#     'partial_vaccinated': 11579,
#     'totally_vaccinated': 7934},
#    {'district_id': 269,
#     'id': 269,
#     'title': 'Dakshina Kannada',
#     'district_name': 'Dakshina Kannada',
#     'total': 48174,
#     'partial_vaccinated': 28061,
#     'totally_vaccinated': 20113},
#    {'district_id': 270,
#     'id': 270,
#     'title': 'Bagalkot',
#     'district_name': 'Bagalkot',
#     'total': 17275,
#     'partial_vaccinated': 12252,
#     'totally_vaccinated': 5023},
#    {'district_id': 271,
#     'id': 271,
#     'title': 'Chamarajanagar',
#     'district_name': 'Chamarajanagar',
#     'total': 8833,
#     'partial_vaccinated': 5768,
#     'totally_vaccinated': 3065},
#    {'district_id': 272,
#     'id': 272,
#     'title': 'Bidar',
#     'district_name': 'Bidar',
#     'total': 14171,
#     'partial_vaccinated': 9557,
#     'totally_vaccinated': 4614},
#    {'district_id': 273,
#     'id': 273,
#     'title': 'Chikamagalur',
#     'district_name': 'Chikamagalur',
#     'total': 18543,
#     'partial_vaccinated': 13048,
#     'totally_vaccinated': 5495},
#    {'district_id': 274,
#     'id': 274,
#     'title': 'Bellary',
#     'district_name': 'Bellary',
#     'total': 27018,
#     'partial_vaccinated': 18036,
#     'totally_vaccinated': 8982},
#    {'district_id': 275,
#     'id': 275,
#     'title': 'Davanagere',
#     'district_name': 'Davanagere',
#     'total': 19993,
#     'partial_vaccinated': 13219,
#     'totally_vaccinated': 6774},
#    {'district_id': 276,
#     'id': 276,
#     'title': 'Bangalore Rural',
#     'district_name': 'Bangalore Rural',
#     'total': 16670,
#     'partial_vaccinated': 12276,
#     'totally_vaccinated': 4394},
#    {'district_id': 277,
#     'id': 277,
#     'title': 'Kolar',
#     'district_name': 'Kolar',
#     'total': 18628,
#     'partial_vaccinated': 11924,
#     'totally_vaccinated': 6704},
#    {'district_id': 278,
#     'id': 278,
#     'title': 'Dharwad',
#     'district_name': 'Dharwad',
#     'total': 27783,
#     'partial_vaccinated': 17862,
#     'totally_vaccinated': 9921},
#    {'district_id': 279,
#     'id': 279,
#     'title': 'Haveri',
#     'district_name': 'Haveri',
#     'total': 11098,
#     'partial_vaccinated': 7298,
#     'totally_vaccinated': 3800},
#    {'district_id': 280,
#     'id': 280,
#     'title': 'Gadag',
#     'district_name': 'Gadag',
#     'total': 15002,
#     'partial_vaccinated': 11328,
#     'totally_vaccinated': 3674},
#    {'district_id': 281,
#     'id': 281,
#     'title': 'Uttar Kannada',
#     'district_name': 'Uttar Kannada',
#     'total': 25055,
#     'partial_vaccinated': 15015,
#     'totally_vaccinated': 10040},
#    {'district_id': 282,
#     'id': 282,
#     'title': 'Koppal',
#     'district_name': 'Koppal',
#     'total': 12967,
#     'partial_vaccinated': 9766,
#     'totally_vaccinated': 3201},
#    {'district_id': 283,
#     'id': 283,
#     'title': 'Kodagu',
#     'district_name': 'Kodagu',
#     'total': 9603,
#     'partial_vaccinated': 5603,
#     'totally_vaccinated': 4000},
#    {'district_id': 284,
#     'id': 284,
#     'title': 'Raichur',
#     'district_name': 'Raichur',
#     'total': 18391,
#     'partial_vaccinated': 11057,
#     'totally_vaccinated': 7334},
#    {'district_id': 285,
#     'id': 285,
#     'title': 'Yadgir',
#     'district_name': 'Yadgir',
#     'total': 7015,
#     'partial_vaccinated': 4255,
#     'totally_vaccinated': 2760},
#    {'district_id': 286,
#     'id': 286,
#     'title': 'Udupi',
#     'district_name': 'Udupi',
#     'total': 30326,
#     'partial_vaccinated': 17179,
#     'totally_vaccinated': 13147},
#    {'district_id': 287,
#     'id': 287,
#     'title': 'Shimoga',
#     'district_name': 'Shimoga',
#     'total': 24648,
#     'partial_vaccinated': 15595,
#     'totally_vaccinated': 9053},
#    {'district_id': 288,
#     'id': 288,
#     'title': 'Tumkur',
#     'district_name': 'Tumkur',
#     'total': 49472,
#     'partial_vaccinated': 34490,
#     'totally_vaccinated': 14982},
#    {'district_id': 289,
#     'id': 289,
#     'title': 'Hassan',
#     'district_name': 'Hassan',
#     'total': 26071,
#     'partial_vaccinated': 18125,
#     'totally_vaccinated': 7946},
#    {'district_id': 290,
#     'id': 290,
#     'title': 'Mandya',
#     'district_name': 'Mandya',
#     'total': 22621,
#     'partial_vaccinated': 14358,
#     'totally_vaccinated': 8263},
#    {'district_id': 291,
#     'id': 291,
#     'title': 'Chikkaballapur',
#     'district_name': 'Chikkaballapur',
#     'total': 13891,
#     'partial_vaccinated': 8134,
#     'totally_vaccinated': 5757},
#    {'district_id': 292,
#     'id': 292,
#     'title': 'Ramanagara',
#     'district_name': 'Ramanagara',
#     'total': 12697,
#     'partial_vaccinated': 7917,
#     'totally_vaccinated': 4780},
#    {'district_id': 293,
#     'id': 293,
#     'title': 'Vijayapura',
#     'district_name': 'Vijayapura',
#     'total': 20726,
#     'partial_vaccinated': 14628,
#     'totally_vaccinated': 6098},
#    {'district_id': 294,
#     'id': 294,
#     'title': 'BBMP',
#     'district_name': 'BBMP',
#     'total': 176872,
#     'partial_vaccinated': 125025,
#     'totally_vaccinated': 51847}],
#   'reportFor': 'State : 16 | 2021-03-10',
#   'timestamp': '2021-03-10 17:30:11'},
#  {'topBlock': {'sites': {'total': 624, 'govt': 307, 'pvt': 317, 'today': None},
#    'sessions': {'total': 104812, 'govt': 40150, 'pvt': 64662, 'today': None},
#    'registration': {'total': None,
#     'male': None,
#     'female': None,
#     'others': None,
#     'today': None},
#    'vaccination': {'total': 895719,
#     'male': 418172,
#     'female': 477414,
#     'others': 133,
#     'covishield': 888302,
#     'covaxin': 7364,
#     'today': 15954,
#     'tot_dose_1': 594042,
#     'tot_dose_2': 301677,
#     'total_doses': 1197396}},
#   'vaccinationDoneByTime': [{'ts': '2021-03-11T04:00:00.000Z',
#     'timestamps': '2021-03-11T10:00:00.000Z',
#     'label': '10:00-11:00',
#     'count': 1188,
#     'dose_one': 983,
#     'dose_two': 205},
#    {'ts': '2021-03-11T12:00:00.000Z',
#     'timestamps': '2021-03-11T18:00:00.000Z',
#     'label': '18:00-19:00',
#     'count': 445,
#     'dose_one': 333,
#     'dose_two': 112},
#    {'ts': '2021-03-11T10:00:00.000Z',
#     'timestamps': '2021-03-11T16:00:00.000Z',
#     'label': '16:00-17:00',
#     'count': 1536,
#     'dose_one': 1167,
#     'dose_two': 369},
#    {'ts': '2021-03-11T14:00:00.000Z',
#     'timestamps': '2021-03-11T20:00:00.000Z',
#     'label': '20:00-21:00',
#     'count': 17,
#     'dose_one': 8,
#     'dose_two': 9},
#    {'ts': '2021-03-11T07:00:00.000Z',
#     'timestamps': '2021-03-11T13:00:00.000Z',
#     'label': '13:00-14:00',
#     'count': 2573,
#     'dose_one': 1971,
#     'dose_two': 602},
#    {'ts': '2021-03-11T06:00:00.000Z',
#     'timestamps': '2021-03-11T12:00:00.000Z',
#     'label': '12:00-13:00',
#     'count': 2958,
#     'dose_one': 2272,
#     'dose_two': 686},
#    {'ts': '2021-03-11T03:00:00.000Z',
#     'timestamps': '2021-03-11T09:00:00.000Z',
#     'label': '09:00-10:00',
#     'count': 212,
#     'dose_one': 169,
#     'dose_two': 43},
#    {'ts': '2021-03-11T08:00:00.000Z',
#     'timestamps': '2021-03-11T14:00:00.000Z',
#     'label': '14:00-15:00',
#     'count': 1759,
#     'dose_one': 1316,
#     'dose_two': 443},
#    {'ts': '2021-03-11T09:00:00.000Z',
#     'timestamps': '2021-03-11T15:00:00.000Z',
#     'label': '15:00-16:00',
#     'count': 1926,
#     'dose_one': 1330,
#     'dose_two': 596},
#    {'ts': '2021-03-11T05:00:00.000Z',
#     'timestamps': '2021-03-11T11:00:00.000Z',
#     'label': '11:00-12:00',
#     'count': 2524,
#     'dose_one': 2004,
#     'dose_two': 520},
#    {'ts': '2021-03-11T11:00:00.000Z',
#     'timestamps': '2021-03-11T17:00:00.000Z',
#     'label': '17:00-18:00',
#     'count': 709,
#     'dose_one': 548,
#     'dose_two': 161},
#    {'ts': '2021-03-11T13:00:00.000Z',
#     'timestamps': '2021-03-11T19:00:00.000Z',
#     'label': '19:00-20:00',
#     'count': 158,
#     'dose_one': 104,
#     'dose_two': 54},
#    {'ts': '2021-03-11T02:00:00.000Z',
#     'timestamps': '2021-03-11T08:00:00.000Z',
#     'label': '08:00-09:00',
#     'count': 5,
#     'dose_one': 5,
#     'dose_two': 0},
#    {'ts': '2021-03-11T15:00:00.000Z',
#     'timestamps': '2021-03-11T21:00:00.000Z',
#     'label': '21:00-22:00',
#     'count': 1,
#     'dose_one': 1,
#     'dose_two': 0}],
#   'last7DaysRegistration': [],
#   'last7DaysVaccination': [{'vaccine_date': '2021-03-04',
#     'count': 14097,
#     'dose_one': 10925,
#     'dose_two': 3172},
#    {'vaccine_date': '2021-03-05',
#     'count': 19882,
#     'dose_one': 14151,
#     'dose_two': 5731},
#    {'vaccine_date': '2021-03-06',
#     'count': 23890,
#     'dose_one': 15269,
#     'dose_two': 8621},
#    {'vaccine_date': '2021-03-07',
#     'count': 2131,
#     'dose_one': 1308,
#     'dose_two': 823},
#    {'vaccine_date': '2021-03-08',
#     'count': 63350,
#     'dose_one': 44095,
#     'dose_two': 19255},
#    {'vaccine_date': '2021-03-09',
#     'count': 45935,
#     'dose_one': 33482,
#     'dose_two': 12453},
#    {'vaccine_date': '2021-03-10',
#     'count': 90817,
#     'dose_one': 70114,
#     'dose_two': 20703}],
#   'getBeneficiariesGroupBy': [{'district_id': 264,
#     'id': 264,
#     'title': 'Belgaum',
#     'district_name': 'Belgaum',
#     'total': 55064,
#     'partial_vaccinated': 32357,
#     'totally_vaccinated': 22707},
#    {'district_id': 265,
#     'id': 265,
#     'title': 'Bangalore Urban',
#     'district_name': 'Bangalore Urban',
#     'total': 39583,
#     'partial_vaccinated': 29086,
#     'totally_vaccinated': 10497},
#    {'district_id': 266,
#     'id': 266,
#     'title': 'Mysore',
#     'district_name': 'Mysore',
#     'total': 48817,
#     'partial_vaccinated': 31441,
#     'totally_vaccinated': 17376},
#    {'district_id': 267,
#     'id': 267,
#     'title': 'Gulbarga',
#     'district_name': 'Gulbarga',
#     'total': 22556,
#     'partial_vaccinated': 15243,
#     'totally_vaccinated': 7313},
#    {'district_id': 268,
#     'id': 268,
#     'title': 'Chitradurga',
#     'district_name': 'Chitradurga',
#     'total': 19667,
#     'partial_vaccinated': 11715,
#     'totally_vaccinated': 7952},
#    {'district_id': 269,
#     'id': 269,
#     'title': 'Dakshina Kannada',
#     'district_name': 'Dakshina Kannada',
#     'total': 50059,
#     'partial_vaccinated': 28820,
#     'totally_vaccinated': 21239},
#    {'district_id': 270,
#     'id': 270,
#     'title': 'Bagalkot',
#     'district_name': 'Bagalkot',
#     'total': 17366,
#     'partial_vaccinated': 12326,
#     'totally_vaccinated': 5040},
#    {'district_id': 271,
#     'id': 271,
#     'title': 'Chamarajanagar',
#     'district_name': 'Chamarajanagar',
#     'total': 8885,
#     'partial_vaccinated': 5808,
#     'totally_vaccinated': 3077},
#    {'district_id': 272,
#     'id': 272,
#     'title': 'Bidar',
#     'district_name': 'Bidar',
#     'total': 14177,
#     'partial_vaccinated': 9558,
#     'totally_vaccinated': 4619},
#    {'district_id': 273,
#     'id': 273,
#     'title': 'Chikamagalur',
#     'district_name': 'Chikamagalur',
#     'total': 18647,
#     'partial_vaccinated': 13137,
#     'totally_vaccinated': 5510},
#    {'district_id': 274,
#     'id': 274,
#     'title': 'Bellary',
#     'district_name': 'Bellary',
#     'total': 27789,
#     'partial_vaccinated': 18470,
#     'totally_vaccinated': 9319},
#    {'district_id': 275,
#     'id': 275,
#     'title': 'Davanagere',
#     'district_name': 'Davanagere',
#     'total': 20229,
#     'partial_vaccinated': 13409,
#     'totally_vaccinated': 6820},
#    {'district_id': 276,
#     'id': 276,
#     'title': 'Bangalore Rural',
#     'district_name': 'Bangalore Rural',
#     'total': 16700,
#     'partial_vaccinated': 12306,
#     'totally_vaccinated': 4394},
#    {'district_id': 277,
#     'id': 277,
#     'title': 'Kolar',
#     'district_name': 'Kolar',
#     'total': 18788,
#     'partial_vaccinated': 11993,
#     'totally_vaccinated': 6795},
#    {'district_id': 278,
#     'id': 278,
#     'title': 'Dharwad',
#     'district_name': 'Dharwad',
#     'total': 28159,
#     'partial_vaccinated': 18171,
#     'totally_vaccinated': 9988},
#    {'district_id': 279,
#     'id': 279,
#     'title': 'Haveri',
#     'district_name': 'Haveri',
#     'total': 11098,
#     'partial_vaccinated': 7298,
#     'totally_vaccinated': 3800},
#    {'district_id': 280,
#     'id': 280,
#     'title': 'Gadag',
#     'district_name': 'Gadag',
#     'total': 15101,
#     'partial_vaccinated': 11400,
#     'totally_vaccinated': 3701},
#    {'district_id': 281,
#     'id': 281,
#     'title': 'Uttar Kannada',
#     'district_name': 'Uttar Kannada',
#     'total': 25437,
#     'partial_vaccinated': 15365,
#     'totally_vaccinated': 10072},
#    {'district_id': 282,
#     'id': 282,
#     'title': 'Koppal',
#     'district_name': 'Koppal',
#     'total': 13181,
#     'partial_vaccinated': 9846,
#     'totally_vaccinated': 3335},
#    {'district_id': 283,
#     'id': 283,
#     'title': 'Kodagu',
#     'district_name': 'Kodagu',
#     'total': 9603,
#     'partial_vaccinated': 5603,
#     'totally_vaccinated': 4000},
#    {'district_id': 284,
#     'id': 284,
#     'title': 'Raichur',
#     'district_name': 'Raichur',
#     'total': 18391,
#     'partial_vaccinated': 11057,
#     'totally_vaccinated': 7334},
#    {'district_id': 285,
#     'id': 285,
#     'title': 'Yadgir',
#     'district_name': 'Yadgir',
#     'total': 7081,
#     'partial_vaccinated': 4290,
#     'totally_vaccinated': 2791},
#    {'district_id': 286,
#     'id': 286,
#     'title': 'Udupi',
#     'district_name': 'Udupi',
#     'total': 30808,
#     'partial_vaccinated': 17540,
#     'totally_vaccinated': 13268},
#    {'district_id': 287,
#     'id': 287,
#     'title': 'Shimoga',
#     'district_name': 'Shimoga',
#     'total': 24852,
#     'partial_vaccinated': 15770,
#     'totally_vaccinated': 9082},
#    {'district_id': 288,
#     'id': 288,
#     'title': 'Tumkur',
#     'district_name': 'Tumkur',
#     'total': 49535,
#     'partial_vaccinated': 34538,
#     'totally_vaccinated': 14997},
#    {'district_id': 289,
#     'id': 289,
#     'title': 'Hassan',
#     'district_name': 'Hassan',
#     'total': 26229,
#     'partial_vaccinated': 18250,
#     'totally_vaccinated': 7979},
#    {'district_id': 290,
#     'id': 290,
#     'title': 'Mandya',
#     'district_name': 'Mandya',
#     'total': 22621,
#     'partial_vaccinated': 14358,
#     'totally_vaccinated': 8263},
#    {'district_id': 291,
#     'id': 291,
#     'title': 'Chikkaballapur',
#     'district_name': 'Chikkaballapur',
#     'total': 13902,
#     'partial_vaccinated': 8145,
#     'totally_vaccinated': 5757},
#    {'district_id': 292,
#     'id': 292,
#     'title': 'Ramanagara',
#     'district_name': 'Ramanagara',
#     'total': 12715,
#     'partial_vaccinated': 7933,
#     'totally_vaccinated': 4782},
#    {'district_id': 293,
#     'id': 293,
#     'title': 'Vijayapura',
#     'district_name': 'Vijayapura',
#     'total': 20802,
#     'partial_vaccinated': 14699,
#     'totally_vaccinated': 6103},
#    {'district_id': 294,
#     'id': 294,
#     'title': 'BBMP',
#     'district_name': 'BBMP',
#     'total': 187469,
#     'partial_vaccinated': 133739,
#     'totally_vaccinated': 53730}],
#   'reportFor': 'State : 16 | 2021-03-11',
#   'timestamp': '2021-03-11 18:02:12'},
#  {'topBlock': {'sites': {'total': 3094,
#     'govt': 2619,
#     'pvt': 475,
#     'today': None},
#    'sessions': {'total': 388300, 'govt': 298900, 'pvt': 89400, 'today': None},
#    'registration': {'total': None,
#     'male': None,
#     'female': None,
#     'others': None,
#     'today': None},
#    'vaccination': {'total': 998460,
#     'male': 471306,
#     'female': 527012,
#     'others': 142,
#     'covishield': 990884,
#     'covaxin': 7523,
#     'today': 102741,
#     'tot_dose_1': 680155,
#     'tot_dose_2': 318305,
#     'total_doses': 1316765}},
#   'vaccinationDoneByTime': [{'ts': '2021-03-12T11:00:00.000Z',
#     'timestamps': '2021-03-12T17:00:00.000Z',
#     'label': '17:00-18:00',
#     'count': 4926,
#     'dose_one': 3625,
#     'dose_two': 1301},
#    {'ts': '2021-03-12T14:00:00.000Z',
#     'timestamps': '2021-03-12T20:00:00.000Z',
#     'label': '20:00-21:00',
#     'count': 254,
#     'dose_one': 207,
#     'dose_two': 47},
#    {'ts': '2021-03-12T05:00:00.000Z',
#     'timestamps': '2021-03-12T11:00:00.000Z',
#     'label': '11:00-12:00',
#     'count': 13041,
#     'dose_one': 11546,
#     'dose_two': 1495},
#    {'ts': '2021-03-12T07:00:00.000Z',
#     'timestamps': '2021-03-12T13:00:00.000Z',
#     'label': '13:00-14:00',
#     'count': 19637,
#     'dose_one': 16869,
#     'dose_two': 2768},
#    {'ts': '2021-03-12T08:00:00.000Z',
#     'timestamps': '2021-03-12T14:00:00.000Z',
#     'label': '14:00-15:00',
#     'count': 13041,
#     'dose_one': 11189,
#     'dose_two': 1852},
#    {'ts': '2021-03-12T10:00:00.000Z',
#     'timestamps': '2021-03-12T16:00:00.000Z',
#     'label': '16:00-17:00',
#     'count': 13560,
#     'dose_one': 10406,
#     'dose_two': 3154},
#    {'ts': '2021-03-12T13:00:00.000Z',
#     'timestamps': '2021-03-12T19:00:00.000Z',
#     'label': '19:00-20:00',
#     'count': 698,
#     'dose_one': 552,
#     'dose_two': 146},
#    {'ts': '2021-03-12T04:00:00.000Z',
#     'timestamps': '2021-03-12T10:00:00.000Z',
#     'label': '10:00-11:00',
#     'count': 3502,
#     'dose_one': 3057,
#     'dose_two': 445},
#    {'ts': '2021-03-12T12:00:00.000Z',
#     'timestamps': '2021-03-12T18:00:00.000Z',
#     'label': '18:00-19:00',
#     'count': 1627,
#     'dose_one': 1166,
#     'dose_two': 461},
#    {'ts': '2021-03-12T17:00:00.000Z',
#     'timestamps': '2021-03-12T23:00:00.000Z',
#     'label': '23:00-00:00',
#     'count': 100,
#     'dose_one': 93,
#     'dose_two': 7},
#    {'ts': '2021-03-12T09:00:00.000Z',
#     'timestamps': '2021-03-12T15:00:00.000Z',
#     'label': '15:00-16:00',
#     'count': 13301,
#     'dose_one': 10725,
#     'dose_two': 2576},
#    {'ts': '2021-03-12T06:00:00.000Z',
#     'timestamps': '2021-03-12T12:00:00.000Z',
#     'label': '12:00-13:00',
#     'count': 18596,
#     'dose_one': 16285,
#     'dose_two': 2311},
#    {'ts': '2021-03-12T16:00:00.000Z',
#     'timestamps': '2021-03-12T22:00:00.000Z',
#     'label': '22:00-23:00',
#     'count': 47,
#     'dose_one': 37,
#     'dose_two': 10},
#    {'ts': '2021-03-12T15:00:00.000Z',
#     'timestamps': '2021-03-12T21:00:00.000Z',
#     'label': '21:00-22:00',
#     'count': 58,
#     'dose_one': 48,
#     'dose_two': 10},
#    {'ts': '2021-03-12T03:00:00.000Z',
#     'timestamps': '2021-03-12T09:00:00.000Z',
#     'label': '09:00-10:00',
#     'count': 327,
#     'dose_one': 251,
#     'dose_two': 76},
#    {'ts': '2021-03-12T02:00:00.000Z',
#     'timestamps': '2021-03-12T08:00:00.000Z',
#     'label': '08:00-09:00',
#     'count': 4,
#     'dose_one': 4,
#     'dose_two': 0}],
#   'last7DaysRegistration': [],
#   'last7DaysVaccination': [{'vaccine_date': '2021-03-05',
#     'count': 19882,
#     'dose_one': 14151,
#     'dose_two': 5731},
#    {'vaccine_date': '2021-03-06',
#     'count': 23890,
#     'dose_one': 15269,
#     'dose_two': 8621},
#    {'vaccine_date': '2021-03-07',
#     'count': 2131,
#     'dose_one': 1308,
#     'dose_two': 823},
#    {'vaccine_date': '2021-03-08',
#     'count': 63350,
#     'dose_one': 44095,
#     'dose_two': 19255},
#    {'vaccine_date': '2021-03-09',
#     'count': 45935,
#     'dose_one': 33482,
#     'dose_two': 12453},
#    {'vaccine_date': '2021-03-10',
#     'count': 90817,
#     'dose_one': 70114,
#     'dose_two': 20703},
#    {'vaccine_date': '2021-03-11',
#     'count': 15954,
#     'dose_one': 12200,
#     'dose_two': 3754}],
#   'getBeneficiariesGroupBy': [{'district_id': 264,
#     'id': 264,
#     'title': 'Belgaum',
#     'district_name': 'Belgaum',
#     'total': 60285,
#     'partial_vaccinated': 36277,
#     'totally_vaccinated': 24008},
#    {'district_id': 265,
#     'id': 265,
#     'title': 'Bangalore Urban',
#     'district_name': 'Bangalore Urban',
#     'total': 41472,
#     'partial_vaccinated': 30457,
#     'totally_vaccinated': 11015},
#    {'district_id': 266,
#     'id': 266,
#     'title': 'Mysore',
#     'district_name': 'Mysore',
#     'total': 54441,
#     'partial_vaccinated': 35638,
#     'totally_vaccinated': 18803},
#    {'district_id': 267,
#     'id': 267,
#     'title': 'Gulbarga',
#     'district_name': 'Gulbarga',
#     'total': 24413,
#     'partial_vaccinated': 16774,
#     'totally_vaccinated': 7639},
#    {'district_id': 268,
#     'id': 268,
#     'title': 'Chitradurga',
#     'district_name': 'Chitradurga',
#     'total': 22055,
#     'partial_vaccinated': 13925,
#     'totally_vaccinated': 8130},
#    {'district_id': 269,
#     'id': 269,
#     'title': 'Dakshina Kannada',
#     'district_name': 'Dakshina Kannada',
#     'total': 53941,
#     'partial_vaccinated': 31281,
#     'totally_vaccinated': 22660},
#    {'district_id': 270,
#     'id': 270,
#     'title': 'Bagalkot',
#     'district_name': 'Bagalkot',
#     'total': 18360,
#     'partial_vaccinated': 13120,
#     'totally_vaccinated': 5240},
#    {'district_id': 271,
#     'id': 271,
#     'title': 'Chamarajanagar',
#     'district_name': 'Chamarajanagar',
#     'total': 9478,
#     'partial_vaccinated': 6291,
#     'totally_vaccinated': 3187},
#    {'district_id': 272,
#     'id': 272,
#     'title': 'Bidar',
#     'district_name': 'Bidar',
#     'total': 15653,
#     'partial_vaccinated': 10724,
#     'totally_vaccinated': 4929},
#    {'district_id': 273,
#     'id': 273,
#     'title': 'Chikamagalur',
#     'district_name': 'Chikamagalur',
#     'total': 21361,
#     'partial_vaccinated': 15536,
#     'totally_vaccinated': 5825},
#    {'district_id': 274,
#     'id': 274,
#     'title': 'Bellary',
#     'district_name': 'Bellary',
#     'total': 31473,
#     'partial_vaccinated': 21569,
#     'totally_vaccinated': 9904},
#    {'district_id': 275,
#     'id': 275,
#     'title': 'Davanagere',
#     'district_name': 'Davanagere',
#     'total': 22757,
#     'partial_vaccinated': 15701,
#     'totally_vaccinated': 7056},
#    {'district_id': 276,
#     'id': 276,
#     'title': 'Bangalore Rural',
#     'district_name': 'Bangalore Rural',
#     'total': 18417,
#     'partial_vaccinated': 13799,
#     'totally_vaccinated': 4618},
#    {'district_id': 277,
#     'id': 277,
#     'title': 'Kolar',
#     'district_name': 'Kolar',
#     'total': 20587,
#     'partial_vaccinated': 13524,
#     'totally_vaccinated': 7063},
#    {'district_id': 278,
#     'id': 278,
#     'title': 'Dharwad',
#     'district_name': 'Dharwad',
#     'total': 30357,
#     'partial_vaccinated': 20054,
#     'totally_vaccinated': 10303},
#    {'district_id': 279,
#     'id': 279,
#     'title': 'Haveri',
#     'district_name': 'Haveri',
#     'total': 11962,
#     'partial_vaccinated': 8034,
#     'totally_vaccinated': 3928},
#    {'district_id': 280,
#     'id': 280,
#     'title': 'Gadag',
#     'district_name': 'Gadag',
#     'total': 16893,
#     'partial_vaccinated': 12895,
#     'totally_vaccinated': 3998},
#    {'district_id': 281,
#     'id': 281,
#     'title': 'Uttar Kannada',
#     'district_name': 'Uttar Kannada',
#     'total': 29235,
#     'partial_vaccinated': 18645,
#     'totally_vaccinated': 10590},
#    {'district_id': 282,
#     'id': 282,
#     'title': 'Koppal',
#     'district_name': 'Koppal',
#     'total': 14231,
#     'partial_vaccinated': 10596,
#     'totally_vaccinated': 3635},
#    {'district_id': 283,
#     'id': 283,
#     'title': 'Kodagu',
#     'district_name': 'Kodagu',
#     'total': 10850,
#     'partial_vaccinated': 6764,
#     'totally_vaccinated': 4086},
#    {'district_id': 284,
#     'id': 284,
#     'title': 'Raichur',
#     'district_name': 'Raichur',
#     'total': 20909,
#     'partial_vaccinated': 13053,
#     'totally_vaccinated': 7856},
#    {'district_id': 285,
#     'id': 285,
#     'title': 'Yadgir',
#     'district_name': 'Yadgir',
#     'total': 7880,
#     'partial_vaccinated': 4928,
#     'totally_vaccinated': 2952},
#    {'district_id': 286,
#     'id': 286,
#     'title': 'Udupi',
#     'district_name': 'Udupi',
#     'total': 35205,
#     'partial_vaccinated': 21197,
#     'totally_vaccinated': 14008},
#    {'district_id': 287,
#     'id': 287,
#     'title': 'Shimoga',
#     'district_name': 'Shimoga',
#     'total': 26208,
#     'partial_vaccinated': 16822,
#     'totally_vaccinated': 9386},
#    {'district_id': 288,
#     'id': 288,
#     'title': 'Tumkur',
#     'district_name': 'Tumkur',
#     'total': 59313,
#     'partial_vaccinated': 43525,
#     'totally_vaccinated': 15788},
#    {'district_id': 289,
#     'id': 289,
#     'title': 'Hassan',
#     'district_name': 'Hassan',
#     'total': 31455,
#     'partial_vaccinated': 22919,
#     'totally_vaccinated': 8536},
#    {'district_id': 290,
#     'id': 290,
#     'title': 'Mandya',
#     'district_name': 'Mandya',
#     'total': 24587,
#     'partial_vaccinated': 16125,
#     'totally_vaccinated': 8462},
#    {'district_id': 291,
#     'id': 291,
#     'title': 'Chikkaballapur',
#     'district_name': 'Chikkaballapur',
# ...
#     'totally_vaccinated': 9901,
#     'today': 1649},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 286,
#     'id': 286,
#     'title': 'Udupi',
#     'district_name': 'Udupi',
#     'total': 183472,
#     'partial_vaccinated': 152098,
#     'totally_vaccinated': 31374,
#     'today': 2670},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 287,
#     'id': 287,
#     'title': 'Shimoga',
#     'district_name': 'Shimoga',
#     'total': 189028,
#     'partial_vaccinated': 166844,
#     'totally_vaccinated': 22184,
#     'today': 6728},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 288,
#     'id': 288,
#     'title': 'Tumkur',
#     'district_name': 'Tumkur',
#     'total': 285416,
#     'partial_vaccinated': 236667,
#     'totally_vaccinated': 48749,
#     'today': 6540},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 289,
#     'id': 289,
#     'title': 'Hassan',
#     'district_name': 'Hassan',
#     'total': 229584,
#     'partial_vaccinated': 198628,
#     'totally_vaccinated': 30956,
#     'today': 7760},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 290,
#     'id': 290,
#     'title': 'Mandya',
#     'district_name': 'Mandya',
#     'total': 228520,
#     'partial_vaccinated': 203490,
#     'totally_vaccinated': 25030,
#     'today': 4613},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 291,
#     'id': 291,
#     'title': 'Chikkaballapur',
#     'district_name': 'Chikkaballapur',
#     'total': 167453,
#     'partial_vaccinated': 152268,
#     'totally_vaccinated': 15185,
#     'today': 3351},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 292,
#     'id': 292,
#     'title': 'Ramanagara',
#     'district_name': 'Ramanagara',
#     'total': 154706,
#     'partial_vaccinated': 139477,
#     'totally_vaccinated': 15229,
#     'today': 4341},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 293,
#     'id': 293,
#     'title': 'Vijayapura',
#     'district_name': 'Vijayapura',
#     'total': 193269,
#     'partial_vaccinated': 176034,
#     'totally_vaccinated': 17235,
#     'today': 4642},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 294,
#     'id': 294,
#     'title': 'BBMP',
#     'district_name': 'BBMP',
#     'total': 1277017,
#     'partial_vaccinated': 1071071,
#     'totally_vaccinated': 205946,
#     'today': 30187}],
#   'reportFor': 'State : 16 | 2021-04-21',
#   'aefiPercentage': 0.036,
#   'vaccinationByAge': {'total': 7004724,
#    'vac_18_25': 190409,
#    'vac_25_40': 434369,
#    'vac_40_60': 3195370,
#    'above_60': 3182837},
#   'timestamp': '2021-04-21 18:03:32'},
#  {'topBlock': {'sites': {'total': 7148,
#     'govt': 6399,
#     'pvt': 749,
#     'today': None},
#    'sessions': {'total': 802100, 'govt': 694800, 'pvt': 107300, 'today': None},
#    'registration': {'total': None,
#     'male': None,
#     'female': None,
#     'others': None,
#     'today': None},
#    'vaccination': {'total': 7158532,
#     'male': 3378086,
#     'female': 3779537,
#     'others': 909,
#     'covishield': 7401089,
#     'covaxin': 788176,
#     'today': 207201,
#     'tot_dose_1': 7158532,
#     'tot_dose_2': 1030733,
#     'total_doses': 8189265,
#     'aefi': 2489}},
#   'vaccinationDoneByTime': [{'ts': '2021-04-22 08',
#     'timestamps': '2021-04-22T09:00:00.000Z',
#     'label': '08:00-09:00',
#     'count': 88,
#     'dose_one': 23,
#     'dose_two': 65},
#    {'ts': '2021-04-22 09',
#     'timestamps': '2021-04-22T10:00:00.000Z',
#     'label': '09:00-10:00',
#     'count': 2034,
#     'dose_one': 791,
#     'dose_two': 1243},
#    {'ts': '2021-04-22 10',
#     'timestamps': '2021-04-22T11:00:00.000Z',
#     'label': '10:00-11:00',
#     'count': 12797,
#     'dose_one': 6675,
#     'dose_two': 6122},
#    {'ts': '2021-04-22 11',
#     'timestamps': '2021-04-22T12:00:00.000Z',
#     'label': '11:00-12:00',
#     'count': 30118,
#     'dose_one': 18344,
#     'dose_two': 11774},
#    {'ts': '2021-04-22 12',
#     'timestamps': '2021-04-22T13:00:00.000Z',
#     'label': '12:00-13:00',
#     'count': 40046,
#     'dose_one': 25555,
#     'dose_two': 14491},
#    {'ts': '2021-04-22 13',
#     'timestamps': '2021-04-22T14:00:00.000Z',
#     'label': '13:00-14:00',
#     'count': 33639,
#     'dose_one': 21660,
#     'dose_two': 11979},
#    {'ts': '2021-04-22 14',
#     'timestamps': '2021-04-22T15:00:00.000Z',
#     'label': '14:00-15:00',
#     'count': 23288,
#     'dose_one': 15096,
#     'dose_two': 8192},
#    {'ts': '2021-04-22 15',
#     'timestamps': '2021-04-22T16:00:00.000Z',
#     'label': '15:00-16:00',
#     'count': 27927,
#     'dose_one': 17858,
#     'dose_two': 10069},
#    {'ts': '2021-04-22 16',
#     'timestamps': '2021-04-22T17:00:00.000Z',
#     'label': '16:00-17:00',
#     'count': 19934,
#     'dose_one': 12661,
#     'dose_two': 7273},
#    {'ts': '2021-04-22 17',
#     'timestamps': '2021-04-22T18:00:00.000Z',
#     'label': '17:00-18:00',
#     'count': 8038,
#     'dose_one': 5481,
#     'dose_two': 2557},
#    {'ts': '2021-04-22 18',
#     'timestamps': '2021-04-22T19:00:00.000Z',
#     'label': '18:00-19:00',
#     'count': 2884,
#     'dose_one': 1942,
#     'dose_two': 942},
#    {'ts': '2021-04-22 19',
#     'timestamps': '2021-04-22T20:00:00.000Z',
#     'label': '19:00-20:00',
#     'count': 2423,
#     'dose_one': 1676,
#     'dose_two': 747},
#    {'ts': '2021-04-22 20',
#     'timestamps': '2021-04-22T21:00:00.000Z',
#     'label': '20:00-21:00',
#     'count': 1939,
#     'dose_one': 1280,
#     'dose_two': 659},
#    {'ts': '2021-04-22 21',
#     'timestamps': '2021-04-22T22:00:00.000Z',
#     'label': '21:00-22:00',
#     'count': 1329,
#     'dose_one': 956,
#     'dose_two': 373},
#    {'ts': '2021-04-22 22',
#     'timestamps': '2021-04-22T23:00:00.000Z',
#     'label': '22:00-23:00',
#     'count': 1431,
#     'dose_one': 1076,
#     'dose_two': 355}],
#   'last7DaysRegistration': [],
#   'last7DaysVaccination': [{'vaccine_date': '2021-04-15',
#     'count': 145191,
#     'dose_one': 117123,
#     'dose_two': 28068,
#     'covishield': 135349,
#     'covaxin': 9842,
#     'aefi': 1},
#    {'vaccine_date': '2021-04-16',
#     'count': 190754,
#     'dose_one': 150836,
#     'dose_two': 39918,
#     'covishield': 174048,
#     'covaxin': 16706,
#     'aefi': 6},
#    {'vaccine_date': '2021-04-17',
#     'count': 259981,
#     'dose_one': 201343,
#     'dose_two': 58638,
#     'covishield': 232040,
#     'covaxin': 27941,
#     'aefi': 5},
#    {'vaccine_date': '2021-04-18',
#     'count': 93513,
#     'dose_one': 73094,
#     'dose_two': 20419,
#     'covishield': 81854,
#     'covaxin': 11659,
#     'aefi': 1},
#    {'vaccine_date': '2021-04-19',
#     'count': 220703,
#     'dose_one': 153871,
#     'dose_two': 66832,
#     'covishield': 188200,
#     'covaxin': 32503,
#     'aefi': 0},
#    {'vaccine_date': '2021-04-20',
#     'count': 199739,
#     'dose_one': 135945,
#     'dose_two': 63794,
#     'covishield': 167794,
#     'covaxin': 31945,
#     'aefi': 9},
#    {'vaccine_date': '2021-04-21',
#     'count': 166692,
#     'dose_one': 112171,
#     'dose_two': 54521,
#     'covishield': 138731,
#     'covaxin': 27960,
#     'aefi': 2}],
#   'last5daySessionStatus': [{'session_date': '2021-04-16',
#     'total': 6263,
#     'planned': 2821,
#     'ongoing': 862,
#     'completed': 2580},
#    {'session_date': '2021-04-18',
#     'total': 5739,
#     'planned': 3077,
#     'ongoing': 836,
#     'completed': 1826},
#    {'session_date': '2021-04-19',
#     'total': 6897,
#     'planned': 2474,
#     'ongoing': 1343,
#     'completed': 3080},
#    {'session_date': '2021-04-15',
#     'total': 5929,
#     'planned': 2777,
#     'ongoing': 864,
#     'completed': 2288},
#    {'session_date': '2021-04-17',
#     'total': 6462,
#     'planned': 2003,
#     'ongoing': 1357,
#     'completed': 3102},
#    {'session_date': '2021-04-21',
#     'total': 6551,
#     'planned': 2561,
#     'ongoing': 1194,
#     'completed': 2796},
#    {'session_date': '2021-04-20',
#     'total': 6937,
#     'planned': 2658,
#     'ongoing': 1264,
#     'completed': 3015}],
#   'getBeneficiariesGroupBy': [{'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 264,
#     'id': 264,
#     'title': 'Belgaum',
#     'district_name': 'Belgaum',
#     'total': 443586,
#     'partial_vaccinated': 386778,
#     'totally_vaccinated': 56808,
#     'today': 14337},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 265,
#     'id': 265,
#     'title': 'Bangalore Urban',
#     'district_name': 'Bangalore Urban',
#     'total': 180053,
#     'partial_vaccinated': 146713,
#     'totally_vaccinated': 33340,
#     'today': 3506},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 266,
#     'id': 266,
#     'title': 'Mysore',
#     'district_name': 'Mysore',
#     'total': 534691,
#     'partial_vaccinated': 474639,
#     'totally_vaccinated': 60052,
#     'today': 14206},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 267,
#     'id': 267,
#     'title': 'Gulbarga',
#     'district_name': 'Gulbarga',
#     'total': 167320,
#     'partial_vaccinated': 143986,
#     'totally_vaccinated': 23334,
#     'today': 4171},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 268,
#     'id': 268,
#     'title': 'Chitradurga',
#     'district_name': 'Chitradurga',
#     'total': 171828,
#     'partial_vaccinated': 148035,
#     'totally_vaccinated': 23793,
#     'today': 5062},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 269,
#     'id': 269,
#     'title': 'Dakshina Kannada',
#     'district_name': 'Dakshina Kannada',
#     'total': 251906,
#     'partial_vaccinated': 203834,
#     'totally_vaccinated': 48072,
#     'today': 5024},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 270,
#     'id': 270,
#     'title': 'Bagalkot',
#     'district_name': 'Bagalkot',
#     'total': 198405,
#     'partial_vaccinated': 177749,
#     'totally_vaccinated': 20656,
#     'today': 4717},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 271,
#     'id': 271,
#     'title': 'Chamarajanagar',
#     'district_name': 'Chamarajanagar',
#     'total': 121619,
#     'partial_vaccinated': 111129,
#     'totally_vaccinated': 10490,
#     'today': 2556},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 272,
#     'id': 272,
#     'title': 'Bidar',
#     'district_name': 'Bidar',
#     'total': 151940,
#     'partial_vaccinated': 129050,
#     'totally_vaccinated': 22890,
#     'today': 4712},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 273,
#     'id': 273,
#     'title': 'Chikamagalur',
#     'district_name': 'Chikamagalur',
#     'total': 161376,
#     'partial_vaccinated': 144995,
#     'totally_vaccinated': 16381,
#     'today': 6553},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 274,
#     'id': 274,
#     'title': 'Bellary',
#     'district_name': 'Bellary',
#     'total': 296154,
#     'partial_vaccinated': 260289,
#     'totally_vaccinated': 35865,
#     'today': 8525},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 275,
#     'id': 275,
#     'title': 'Davanagere',
#     'district_name': 'Davanagere',
#     'total': 154357,
#     'partial_vaccinated': 132746,
#     'totally_vaccinated': 21611,
#     'today': 2954},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 276,
#     'id': 276,
#     'title': 'Bangalore Rural',
#     'district_name': 'Bangalore Rural',
#     'total': 111368,
#     'partial_vaccinated': 93969,
#     'totally_vaccinated': 17399,
#     'today': 3575},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 277,
#     'id': 277,
#     'title': 'Kolar',
#     'district_name': 'Kolar',
#     'total': 155283,
#     'partial_vaccinated': 134341,
#     'totally_vaccinated': 20942,
#     'today': 4692},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 278,
#     'id': 278,
#     'title': 'Dharwad',
#     'district_name': 'Dharwad',
#     'total': 198406,
#     'partial_vaccinated': 170664,
#     'totally_vaccinated': 27742,
#     'today': 5885},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 279,
#     'id': 279,
#     'title': 'Haveri',
#     'district_name': 'Haveri',
#     'total': 115134,
#     'partial_vaccinated': 104241,
#     'totally_vaccinated': 10893,
#     'today': 2315},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 280,
#     'id': 280,
#     'title': 'Gadag',
#     'district_name': 'Gadag',
#     'total': 122417,
#     'partial_vaccinated': 104501,
#     'totally_vaccinated': 17916,
#     'today': 1916},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 281,
#     'id': 281,
#     'title': 'Uttar Kannada',
#     'district_name': 'Uttar Kannada',
#     'total': 193873,
#     'partial_vaccinated': 163342,
#     'totally_vaccinated': 30531,
#     'today': 5784},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 282,
#     'id': 282,
#     'title': 'Koppal',
#     'district_name': 'Koppal',
#     'total': 160645,
#     'partial_vaccinated': 143666,
#     'totally_vaccinated': 16979,
#     'today': 1904},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 283,
#     'id': 283,
#     'title': 'Kodagu',
#     'district_name': 'Kodagu',
#     'total': 72951,
#     'partial_vaccinated': 62591,
#     'totally_vaccinated': 10360,
#     'today': 2396},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 284,
#     'id': 284,
#     'title': 'Raichur',
#     'district_name': 'Raichur',
#     'total': 152811,
#     'partial_vaccinated': 131702,
#     'totally_vaccinated': 21109,
#     'today': 3081},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 285,
#     'id': 285,
#     'title': 'Yadgir',
#     'district_name': 'Yadgir',
#     'total': 97517,
#     'partial_vaccinated': 86493,
#     'totally_vaccinated': 11024,
#     'today': 1921},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 286,
#     'id': 286,
#     'title': 'Udupi',
#     'district_name': 'Udupi',
#     'total': 188205,
#     'partial_vaccinated': 154520,
#     'totally_vaccinated': 33685,
#     'today': 4311},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 287,
#     'id': 287,
#     'title': 'Shimoga',
#     'district_name': 'Shimoga',
#     'total': 196865,
#     'partial_vaccinated': 173335,
#     'totally_vaccinated': 23530,
#     'today': 7837},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 288,
#     'id': 288,
#     'title': 'Tumkur',
#     'district_name': 'Tumkur',
#     'total': 293800,
#     'partial_vaccinated': 241998,
#     'totally_vaccinated': 51802,
#     'today': 8384},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 289,
#     'id': 289,
#     'title': 'Hassan',
#     'district_name': 'Hassan',
#     'total': 239796,
#     'partial_vaccinated': 205574,
#     'totally_vaccinated': 34222,
#     'today': 10149},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 290,
#     'id': 290,
#     'title': 'Mandya',
#     'district_name': 'Mandya',
#     'total': 236499,
#     'partial_vaccinated': 208671,
#     'totally_vaccinated': 27828,
#     'today': 7979},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 291,
#     'id': 291,
#     'title': 'Chikkaballapur',
#     'district_name': 'Chikkaballapur',
#     'total': 173634,
#     'partial_vaccinated': 157091,
#     'totally_vaccinated': 16543,
#     'today': 6161},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 292,
#     'id': 292,
#     'title': 'Ramanagara',
#     'district_name': 'Ramanagara',
#     'total': 157194,
#     'partial_vaccinated': 141254,
#     'totally_vaccinated': 15940,
#     'today': 2488},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 293,
#     'id': 293,
#     'title': 'Vijayapura',
#     'district_name': 'Vijayapura',
#     'total': 197617,
#     'partial_vaccinated': 179121,
#     'totally_vaccinated': 18496,
#     'today': 4280},
#    {'state_id': 16,
#     'state_name': 'Karnataka',
#     'district_id': 294,
#     'id': 294,
#     'title': 'BBMP',
#     'district_name': 'BBMP',
#     'total': 1319099,
#     'partial_vaccinated': 1092968,
#     'totally_vaccinated': 226131,
#     'today': 41927}],
#   'reportFor': 'State : 16 | 2021-04-22',
#   'aefiPercentage': 0.035,
#   'vaccinationByAge': {'total': 7158532,
#    'vac_18_25': 191325,
#    'vac_25_40': 440206,
#    'vac_40_60': 3289216,
#    'above_60': 3236032},
#   'timestamp': '2021-04-22 17:30:20'}]

# %%
def prep_for_pdf(state_code, district_code):
    WIDTH = 210
    HEIGHT = 297
    pdf = FPDF()
    pdf.add_page()
    pdf.ln(60)
    pdf.set_font('Arial', 'B', 16)
    pdf.write(25, f'COVID Vaccine Analysis Report for State: {state_code}, District: {district_code}')
    pdf.ln(20)
    pdf.write(5, '''This report analyzes the following:
              - The Number of Site Statistics for the State
              - Gender Wise Vaccination Distribution in the State
              - Dose Wise Statistics for the State
              - Statistics for Different Kinds of Vaccine in the State
              - Number of Vaccinations in the District
              - Data Table for the Vaccination Trends in the District
              ''')
    pdf.ln(40)
    pdf.add_page()
    get_district_changes(district_code, state_code)
    plot_district_changes(district_code, state_code)
    plot_genderwise_state(state_code)
    plot_dosewise_state(state_code)
    plot_site_stats(state_code)
    plot_diff_vacc(state_code)
    pdf.image(f'site_stats_{state_code}.png',5, 10, WIDTH-10)
    pdf.image(f'genderwise_state_{state_code}.png',5, 120, WIDTH-10)
    pdf.add_page()
    pdf.image(f'dosewise_state_{state_code}.png',5, 10, WIDTH-10)
    pdf.image(f'diff_vaccine_stats_{state_code}.png',5, 120, WIDTH-10)
    pdf.add_page()
    pdf.image(f'district_changes_{district_code}_{state_code}.png',5, 10, WIDTH-10)
    pdf.add_page()
    pdf.image(f'datatable_{state_code}_{district_code}.png',5,10, 200)
    pdf.output(f'State_{state_code}_district_{district_code}' + '.pdf')

# %%
prep_for_pdf(9, 142)

# %% [markdown]
# # District Analysis

# %%
def get_district_data(state_code, district_code):
    ls = []
    ls_for_index = []
    for index, filename in enumerate(os.scandir(directory)):
        if filename.is_file():
            if str(filename.path).startswith(f'data\CoWIN_IN_{state_code}_{district_code}_2021'):
                f = open(filename.path,)
                data = json.load(f)
                ls.append(data)
                ls_for_index.append(' '.join(list(filename.path.split('\\')[1].split('.')[0].split(f'{district_code}_')[1].split('-'))))
    return ls, ls_for_index

# %%
ls, ls_for_index = get_district_data(5,83)

# %%
def get_district_dfs(state_code, district_code):
    
    ls, ls_for_index = get_district_data(state_code, district_code)
    df_district_wise = pd.DataFrame() 
    df_district_wise['date-index'] = ls_for_index
    df_district_wise['date-index'] =  pd.to_datetime(df['date-index'], format='%Y %m %d')
    df_district_wise.reset_index().set_index('date-index')
    ls_total_sites = []
    
    for i in range(len(ls)):
        try:
            ls_total_sites.append(ls[i]['topBlock']['sites']['total'])
        except:
            ls_total_sites.append(None)
    ls_total_sites.extend([0,0])
    df_district_wise['total_sites'] = ls_total_sites

    ls_govt_sites = []
    for i in range(len(ls)):
        try:
            ls_govt_sites.append(ls[i]['topBlock']['sites']['govt'])
        except:
            ls_govt_sites.append(None)
    df_district_wise['govt_sites'] = ls_govt_sites

    ls_pvt_sites = []
    for i in range(len(ls)):
        try:
            ls_pvt_sites.append(ls[i]['topBlock']['sites']['pvt'])
        except:
            ls_pvt_sites.append(None)
    df_district_wise['pvt_sites'] = ls_pvt_sites
    df_district_wise = df.reset_index(drop=True)

    ls_total_sessions = []
    for i in range(len(ls)):
        try:
            ls_total_sessions.append(ls[i]['topBlock']['sessions']['total'])
        except:
            ls_total_sessions.append(None)
    df_district_wise['total_sessions'] = ls_total_sessions

    ls_govt_sessions = []
    for i in range(len(ls)):
        try:
            ls_govt_sessions.append(ls[i]['topBlock']['sessions']['govt'])
        except:
            ls_govt_sessions.append(None)
    df_district_wise['govt_sessions'] = ls_govt_sessions

    ls_pvt_sessions = []
    for i in range(len(ls)):
        try:
            ls_pvt_sessions.append(ls[i]['topBlock']['sessions']['pvt'])
        except:
            ls_pvt_sessions.append(None)
    df_district_wise['pvt_sessions'] = ls_pvt_sessions

    ls_total_vaccine_cumulative = []
    for i in range(len(ls)):
        try:
            ls_total_vaccine_cumulative.append(ls[i]['topBlock']['vaccination']['total'])
        except:
            ls_total_vaccine_cumulative.append(None)
    df_district_wise['total_vacc_cumulative'] = ls_total_vaccine_cumulative

    ls_vac_male = []
    for i in range(len(ls)):
        try:
            ls_vac_male.append(ls[i]['topBlock']['vaccination']['male'])
        except:
            ls_vac_male.append(None)
    df_district_wise['vacc_male'] = ls_vac_male

    ls_vac_female = []
    for i in range(len(ls)):
        try:
            ls_vac_female.append(ls[i]['topBlock']['vaccination']['female'])
        except:
            ls_vac_female.append(None)
    df_district_wise['vacc_female'] = ls_vac_female
    
    ls_vac_others = []
    for i in range(len(ls)):
        try:
            ls_vac_others.append(ls[i]['topBlock']['vaccination']['others'])
        except:
            ls_vac_others.append(None)
    df_district_wise['vacc_others'] = ls_vac_others

    ls_covishield = []
    for i in range(len(ls)):
        try:
            ls_covishield.append(ls[i]['topBlock']['vaccination']['covishield'])
        except:
            ls_covishield.append(None)
    df_district_wise['covishield'] = ls_covishield
    
    ls_covaxin = []
    for i in range(len(ls)):
        try:
            ls_covaxin.append(ls[i]['topBlock']['vaccination']['covaxin'])
        except:
            ls_covaxin.append(None)
    df_district_wise['covaxin'] = ls_covaxin
    
    ls_today = []
    for i in range(len(ls)):
        try:
            ls_today.append(ls[i]['topBlock']['vaccination']['today'])
        except:
            ls_today.append(None)
    df_district_wise['today'] = ls_today
    
    ls_total_dose_1 = []
    for i in range(len(ls)):
        try:
            ls_total_dose_1.append(ls[i]['topBlock']['vaccination']['tot_dose_1'])
        except:
            ls_total_dose_1.append(None)
    df_district_wise['total_dose_1'] = ls_total_dose_1
    
    ls_total_dose_2 = []
    for i in range(len(ls)):
        try:
            ls_total_dose_2.append(ls[i]['topBlock']['vaccination']['tot_dose_2'])
        except:
            ls_total_dose_2.append(None)
    df_district_wise['total_dose_2'] = ls_total_dose_2
    
    ls_total_doses = []
    for i in range(len(ls)):
        try:
            ls_total_doses.append(ls[i]['topBlock']['vaccination']['total_doses'])
        except:
            ls_total_doses.append(None)
    df_district_wise['total_doses'] = ls_total_doses
    
    ls_vac_18_25 = []
    for i in range(len(ls)):
        try:
            ls_vac_18_25.append(ls[i]['vaccinationByAge']['vac_18_25'])
        except:
            ls_vac_18_25.append(None)
    df_district_wise['vac_18_25'] = ls_vac_18_25
    
    ls_vac_25_40 = []
    for i in range(len(ls)):
        try:
            ls_vac_25_40.append(ls[i]['vaccinationByAge']['vac_25_40'])
        except:
            ls_vac_25_40.append(None)
    df_district_wise['vac_25_40'] = ls_vac_25_40
    
    ls_vac_40_60 = []
    for i in range(len(ls)):
        try:
            ls_vac_40_60.append(ls[i]['vaccinationByAge']['vac_40_60'])
        except:
            ls_vac_40_60.append(None)
    df_district_wise['vac_40_60'] = ls_vac_40_60
    
    ls_vac_above_60 = []
    for i in range(len(ls)):
        try:
            ls_vac_above_60.append(ls[i]['vaccinationByAge']['above_60'])
        except:
            ls_vac_above_60.append(None)
    df_district_wise['vac_above_60'] = ls_vac_above_60
    
    ls_session_site_id = []
    ls_session_site_name = []
    ls_title = []
    ls_vacc_district = []
    ls_total_vacc_district = []
    ls_partial_vacc_district = []
    df_session_site = pd.DataFrame() 
    for i in range(len(ls)):
        for j in range(len((ls[i]['getBeneficiariesGroupBy']))):
            try:
                ls_session_site_id.append(ls[i]['getBeneficiariesGroupBy'][j]['session_site_id'])
            except:
                ls_session_site_id.append(None)
            try:
                ls_session_site_name.append(ls[i]['getBeneficiariesGroupBy'][j]['session_site_name'])
            except:
                ls_session_site_name.append(None)
            try:
                ls_title.append(ls[i]['getBeneficiariesGroupBy'][j]['title'])
            except:
                ls_title.append(None)     
            try:
                ls_vacc_district.append(ls[i]['getBeneficiariesGroupBy'][j]['total'])
            except:
                ls_vacc_district.append(None)   
            try:
                ls_total_vacc_district.append(ls[i]['getBeneficiariesGroupBy'][j]['totally_vaccinated'])
            except:
                ls_total_vacc_district.append(None)   
            try:
                ls_partial_vacc_district.append(ls[i]['getBeneficiariesGroupBy'][j]['partial_vaccinated'])
            except:
                ls_partial_vacc_district.append(None)  
    df_session_site['session_site_id'] = ls_session_site_id
    df_session_site['session_site_name'] = ls_session_site_name
    df_session_site['title'] = ls_title
    df_session_site['vaccinatated_in_district_partial_and_total'] = ls_vacc_district
    df_session_site['vaccinatated_in_district_total'] = ls_total_vacc_district
    df_session_site['vaccinatated_in_district_partial'] = ls_partial_vacc_district
    return df_district_wise, df_session_site

# %%
df_district, df_session_site = get_district_dfs(16, 264)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-cc8fdb9233c9> in <module>
# ----> 1 df_district, df_session_site = get_district_dfs(16, 264)
#
# <ipython-input-83-2db6a8d22b93> in get_district_dfs(state_code, district_code)
#      14             ls_total_sites.append(None)
#      15     ls_total_sites.extend([0,0])
# ---> 16     df_district_wise['total_sites'] = ls_total_sites
#      17
#      18     ls_govt_sites = []
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
#    3763             # turn me into an ndarray
# -> 3764             value = sanitize_index(value, self.index)
#    3765             if not isinstance(value, (np.ndarray, Index)):
#    3766                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     745     """
#     746     if len(data) != len(index):
# --> 747         raise ValueError(
#     748             "Length of values "
#     749             f"({len(data)}) "
#
# ValueError: Length of values (46) does not match length of index (44)

# %%
df_district
# Out:
#    date-index  total_sites  govt_sites  pvt_sites  total_sessions  \
# 0  2021-03-08          183         172         11           21900
# 1  2021-03-09           99          88         11           11800
# 2  2021-03-10          182         170         12           21200
# 3  2021-03-11            0           0          0               0
# 4  2021-03-12          182         169         13           20900
# 5  2021-03-13           11           3          8            1500
# 6  2021-03-14            4           3          1             500
# 7  2021-03-15          192         178         14           21780
# 8  2021-03-16          115          97         18           13480
# 9  2021-03-17          201         180         21           23480
# 10 2021-03-18          206         181         25           22780
# 11 2021-03-19          212         183         29           25980
# 12 2021-03-20          215         185         30           24980
# 13 2021-03-21           95          87          8            9800
# 14 2021-03-22          216         186         30           24080
# 15 2021-03-23          215         187         28           23180
# 16 2021-03-24          216         189         27           23480
# 17 2021-03-25          224         195         29           23880
# 18 2021-03-26          223         195         28           23580
# 19 2021-03-27          222         195         27           23580
# 20 2021-03-28          200         186         14           20800
# 21 2021-03-29          217         195         22           23880
# 22 2021-03-30          223         195         28           23830
# 23 2021-03-31          223         195         28           24580
# 24 2021-04-01          230         207         23           24400
# 25 2021-04-02          239         214         25           25400
# 26 2021-04-03          238         215         23           25000
# 27 2021-04-04          227         208         19           26100
# 28 2021-04-05          229         206         23           24800
# 29 2021-04-06          300         272         28           33700
# 30 2021-04-07          404         378         26           41700
# 31 2021-04-08          420         387         33           44701
# 32 2021-04-09          467         437         30           47600
# 33 2021-04-10          450         422         28           45700
# 34 2021-04-11          369         342         27           39460
# 35 2021-04-12          423         389         34           45060
# 36 2021-04-13          312         280         32           33760
# 37 2021-04-14          386         351         35           40560
# 38 2021-04-15          364         326         38           39260
# 39 2021-04-16          409         372         37           43660
# 40 2021-04-19          488         457         31           51860
# 41 2021-04-20          469         436         33           49260
# 42 2021-04-21          468         436         32           48460
# 43 2021-04-22          453         418         35           48460
#
#     govt_sessions  pvt_sessions  total_vacc_cumulative  vacc_male  \
# 0           20300          1600                  48613      21680
# 1           10100          1700                  50802      22821
# 2           19400          1800                  55062      25091
# 3               0             0                  55064      25092
# 4           18800          2100                  60285      28049
# 5             500          1000                  60846      28268
# 6             400           100                  60876      28283
# 7           19880          1900                  68612      32336
# 8           10980          2500                  67971      32054
# 9           20380          3100                  79081      37801
# 10          19380          3400                  83381      40037
# 11          22280          3700                  93971      45184
# 12          21080          3900                 103733      49868
# 13           8900           900                 106151      50946
# 14          20380          3700                 117969      56452
# 15          19680          3500                 131169      62598
# 16          20280          3200                 143912      68431
# 17          20580          3300                 156186      73993
# 18          20480          3100                 167271      79023
# 19          20580          3000                 173517      81837
# 20          19400          1400                 176716      83267
# 21          21180          2700                 183602      86199
# 22          20530          3300                 197246      92152
# 23          21180          3400                 208930      97191
# 24          21700          2700                 216363     100553
# 25          22500          2900                 224597     104227
# 26          22500          2500                 228757     106052
# 27          23900          2200                 231990     107522
# 28          22000          2800                 233734     108302
# 29          30300          3400                 236995     109717
# 30          38800          2900                 266368     122374
# 31          40700          4001                 292643     133773
# 32          44200          3400                 319530     145759
# 33          42800          2900                 341665     156074
# 34          36360          3100                 349172     159521
# 35          40960          4100                 363488     166319
# 36          29860          3900                 364102     166663
# 37          36360          4200                 367990     168540
# 38          34660          4600                 369838     169440
# 39          39160          4500                 373234     171074
# 40          48160          3700                 408142     187595
# 41          45360          3900                 423704     195204
# 42          44760          3700                 438753     202307
# 43          44660          3800                 452085     208734
#
#     vacc_female  ...  covishield  covaxin  today  total_dose_1  total_dose_2  \
# 0         26928  ...       48612        0   3019           NaN           NaN
# 1         27976  ...       50801        0   2189       29173.0       21629.0
# 2         29966  ...       55061        0   4260       32356.0       22706.0
# 3         29967  ...       55063        0      1       32357.0       22707.0
# 4         32229  ...       60284        0   5221       36277.0       24008.0
# 5         32571  ...       60845        0    561       36569.0       24277.0
# 6         32586  ...       60875        0     30       36599.0       24277.0
# 7         36269  ...       68385      226   7736       43384.0       25228.0
# 8         35909  ...       93352      618   3916       67971.0       25999.0
# 9         41271  ...      104802     1039   9592       79081.0       26760.0
# 10        43335  ...      109307     1412   4653       83381.0       27338.0
# 11        48778  ...      120166     1764  10889       93971.0       27959.0
# 12        53856  ...      130148     2324   9342      103733.0       28739.0
# 13        55195  ...      132347     2628   1777      106151.0       28824.0
# 14        61505  ...      143918     3296  12084      117969.0       29245.0
# 15        68556  ...      156622     4604  11001      131169.0       30057.0
# 16        75465  ...      168455     6030  13041      143912.0       30573.0
# 17        82177  ...      179133     8190  12584      156186.0       31137.0
# 18        88232  ...      189114     9666  11279      167271.0       31509.0
# 19        91662  ...      194770    10508   5926      173517.0       31761.0
# 20        93430  ...      197941    10574   3006      176716.0       31799.0
# 21        97384  ...      204655    10819   6918      183602.0       31872.0
# 22       105073  ...      218271    11295  13927      197246.0       32320.0
# 23       111718  ...      230020    11527  11753      208930.0       32617.0
# 24       115788  ...      237623    11629   7540      216363.0       32889.0
# 25       120346  ...      245775    11981   5063      224597.0       33159.0
# 26       122681  ...      249911    12152   3201      228757.0       33306.0
# 27       124443  ...      252878    12553    438      231990.0       33441.0
# 28       125407  ...      254758    12592   1782      233734.0       33616.0
# 29       127252  ...      258117    12624   2404      236995.0       33746.0
# 30       143965  ...      288229    12638  18375      266368.0       34499.0
# 31       158838  ...      315372    12638  19906      292643.0       35367.0
# 32       173736  ...      343182    12638  26727      319530.0       36290.0
# 33       185550  ...      366091    12638  21715      341665.0       37064.0
# 34       189610  ...      373827    12640   5430      349172.0       37295.0
# 35       197126  ...      388926    12640  14546      363488.0       38078.0
# 36       197396  ...      389609    12640    560      364102.0       38147.0
# 37       199404  ...      394013    12640   4063      367990.0       38663.0
# 38       200351  ...      396200    12640   2117      369838.0       39002.0
# 39       202113  ...      399909    12831   3314      373234.0       39506.0
# 40       220487  ...      441062    13843  22066      408142.0       46763.0
# 41       228435  ...      459960    14294  16847      423704.0       50550.0
# 42       236380  ...      478767    14649  16892      438753.0       54663.0
# 43       243284  ...      495314    15096  14813      452085.0       58325.0
#
#     total_doses  vac_18_25  vac_25_40  vac_40_60  vac_above_60
# 0           NaN        NaN        NaN        NaN           NaN
# 1       72431.0        NaN        NaN        NaN           NaN
# 2       77768.0        NaN        NaN        NaN           NaN
# 3       77771.0        NaN        NaN        NaN           NaN
# 4       84293.0        NaN        NaN        NaN           NaN
# 5       85123.0        NaN        NaN        NaN           NaN
# 6       85153.0        NaN        NaN        NaN           NaN
# 7       93840.0        NaN        NaN        NaN           NaN
# 8       93970.0        NaN        NaN        NaN           NaN
# 9      105841.0        NaN        NaN        NaN           NaN
# 10     110719.0        NaN        NaN        NaN           NaN
# 11     121930.0        NaN        NaN        NaN           NaN
# 12     132472.0        NaN        NaN        NaN           NaN
# 13     134975.0        NaN        NaN        NaN           NaN
# 14     147214.0     9053.0    21767.0    34732.0       52324.0
# 15     161226.0     9220.0    22141.0    38498.0       61217.0
# 16     174485.0     9276.0    22403.0    42126.0       70014.0
# 17     187323.0     9373.0    22701.0    46031.0       77988.0
# 18     198780.0     9423.0    22942.0    49472.0       85341.0
# 19     205278.0     9489.0    23107.0    51723.0       89105.0
# 20     208515.0     9495.0    23171.0    52964.0       90993.0
# 21     215474.0     9517.0    23293.0    55447.0       95252.0
# 22     229566.0     9609.0    23552.0    60053.0      103939.0
# 23     241547.0     9642.0    23751.0    64322.0      111122.0
# 24     249252.0     9680.0    23903.0    67995.0      114691.0
# 25     257756.0     9772.0    24059.0    72293.0      118379.0
# 26     262063.0     9821.0    24172.0    74651.0      120019.0
# 27     265431.0     9863.0    24265.0    76569.0      121199.0
# 28     267350.0     9863.0    24255.0    77539.0      121983.0
# 29     270741.0     9864.0    24256.0    79295.0      123485.0
# 30     300867.0     9864.0    24274.0    96010.0      136124.0
# 31     328010.0     9887.0    24314.0   111088.0      147257.0
# 32     355820.0     9911.0    24427.0   127149.0      157946.0
# 33     378729.0     9921.0    24535.0   140662.0      166450.0
# 34     386467.0     9925.0    24552.0   145342.0      169256.0
# 35     401566.0     9958.0    24686.0   154073.0      174674.0
# 36     402249.0     9959.0    24701.0   154465.0      174880.0
# 37     406653.0     9968.0    24733.0   156924.0      176267.0
# 38     408840.0     9971.0    24747.0   158011.0      177011.0
# 39     412740.0     9983.0    24776.0   160165.0      178212.0
# 40     454905.0    10071.0    25210.0   181019.0      191744.0
# 41     474254.0    10131.0    25477.0   190276.0      197722.0
# 42     493416.0    10153.0    25861.0   199161.0      203480.0
# 43     510410.0    10174.0    26132.0   207212.0      208469.0
#
# [44 rows x 21 columns]

# %%
df_sub_div_district
# Out:
#        session_site_id               session_site_name  \
# 0               430134           Shiraguppi PHC Athani
# 1               430197                 Sankaratti PHCi
# 2               430224               Kagwad CHC Athani
# 3               430225                       Athani GH
# 4               430263                  BUDARKATTI PHC
# ...                ...                             ...
# 17001           686484    KASAI GALLI SC RUKMINI NAGAR
# 17002           686857              Adahalli SC Athani
# 17003           686967  AMBEDKAR NAGAR SC VINAYAKNAGAR
# 17004           687079               Satti-A SC Athani
# 17005           687785                RUKMINI NAGAR SC
#
#                                 title  \
# 0               Shiraguppi PHC Athani
# 1                     Sankaratti PHCi
# 2                   Kagwad CHC Athani
# 3                           Athani GH
# 4                      BUDARKATTI PHC
# ...                               ...
# 17001    KASAI GALLI SC RUKMINI NAGAR
# 17002              Adahalli SC Athani
# 17003  AMBEDKAR NAGAR SC VINAYAKNAGAR
# 17004               Satti-A SC Athani
# 17005                RUKMINI NAGAR SC
#
#        vaccinatated_in_district_partial_and_total  \
# 0                                             118
# 1                                              67
# 2                                              94
# 3                                             660
# 4                                              63
# ...                                           ...
# 17001                                         180
# 17002                                          61
# 17003                                         513
# 17004                                          22
# 17005                                          90
#
#        vaccinatated_in_district_total  vaccinatated_in_district_partial
# 0                                  81                                37
# 1                                  57                                10
# 2                                  81                                13
# 3                                 239                               421
# 4                                  63                                 0
# ...                               ...                               ...
# 17001                               5                               175
# 17002                               3                                58
# 17003                              28                               485
# 17004                               0                                22
# 17005                               2                                88
#
# [17006 rows x 6 columns]

# %%
def get_session_site_changes(district_code, state_code, session_site_id):
    df, df_district = get_state_dfs(state_code)
    df_some_district = df_district.loc[df_district['district_id'] == district_code]
    dfi.export(df_some_district,f"datatable_{state_code}_{district_code}.png")
    return df_some_district

def plot_district_changes(district_code, state_code):
    plt.figure(figsize=(20,10))
    df_some_district = get_district_changes(district_code, state_code)
    plt.plot(df_some_district['vaccinatated_in_district_partial_and_total'], label = 'All Vaccinations')
    plt.plot(df_some_district['vaccinatated_in_district_total'], label = 'Completed Vaccinations')
    plt.plot(df_some_district['vaccinatated_in_district_partial'], label = 'Partial Vaccinations')
    plt.legend()
    plt.title(f'Vaccination Curves for District Number {district_code}')
    plt.savefig(f'district_changes_{district_code}_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)
    
    
def plot_genderwise_state(state_code):
    df, df_district = get_state_dfs(state_code)
    plt.figure(figsize=(20,10))
    plt.plot(df['vacc_male'], label = 'Male Vaccination')
    plt.plot(df['vacc_female'], label = 'Female Vaccinations')
    plt.plot(df['vacc_others'], label = 'Other Vaccinations')
    plt.title(f'Gender Wise Stats for State:{state_code}')
    plt.legend()
    plt.savefig(f'genderwise_state_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)

def plot_dosewise_state(state_code):
    df, df_district = get_state_dfs(state_code)
    plt.figure(figsize=(20,10))
    plt.plot(df['total_dose_1'], label = 'Total Dose 1')
    plt.plot(df['total_dose_2'], label = 'Total Dose 2')
    plt.plot(df['total_doses'], label = 'Total Doses')
    plt.legend()
    plt.title(f'Dose Wise Stats for State:{state_code}')
    plt.savefig(f'dosewise_state_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)
    
def plot_site_stats(state_code):
    plt.figure(figsize=(20,10))
    df, df_district = get_state_dfs(state_code)
    plt.plot(df['total_sites'], label = 'Total Sites')
    plt.plot(df['govt_sites'], label = 'Government Sites')
    plt.plot(df['pvt_sites'], label = 'Private Sites')
    plt.legend()
    plt.title(f'Site wise Stats for State:{state_code}')
    plt.savefig(f'site_stats_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)
    
def plot_diff_vacc(state_code):
    plt.figure(figsize=(20,10))
    df, df_district = get_state_dfs(state_code)
    plt.plot(df['covaxin'], label = 'Covaxin')
    plt.plot(df['covishield'], label = 'Covishield')
    plt.legend()
    plt.title(f'Different Kinds of Vaccine Stats for State:{state_code}')
    plt.savefig(f'diff_vaccine_stats_{state_code}.png', bbox_inches = 'tight',
    pad_inches = 2)
    
plot_diff_vacc(16)

# %%
df_district_wise = pd.DataFrame()

# %%
ls_total_sites = []
for i in range(len(ls)):
    try:
        ls_total_sites.append(ls[i]['topBlock']['sites']['total'])
    except:
        ls_total_sites.append(None)
df_district_wise['total_sites'] = ls_total_sites

# %%
df_district_wise
# Out:
#     total_sites
# 0            90
# 1            48
# 2            49
# 3             0
# 4            74
# 5            72
# 6             0
# 7            73
# 8            68
# 9            67
# 10           67
# 11           65
# 12           74
# 13            0
# 14           75
# 15           70
# 16           64
# 17           71
# 18           73
# 19           60
# 20           62
# 21           12
# 22           71
# 23           70
# 24           77
# 25           24
# 26           48
# 27           91
# 28           71
# 29           71
# 30           11
# 31           62
# 32           74
# 33           74
# 34           75
# 35           75
# 36           73
# 37           73
# 38           74
# 39           75
# 40           75
# 41           74
# 42           74
# 43           74
